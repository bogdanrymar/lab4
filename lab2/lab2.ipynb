# %% [markdown]
# # Lab 2
#
# **ПОПЕРЕДНЯ ОБРОБКА ТЕКСТУ**

# %%
import nltk
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer, SnowballStemmer, LancasterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
import pandas as pd
import re

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Darklight\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Darklight\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Darklight\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Darklight\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ## Load Text
#
# [Source](https://arunkprasad.com/log/unlearning-perfectionism)

# %%
with open('article.txt', 'r', encoding='utf-8') as f:
    text = f.read()
text
# Out:
# 'Unlearning Perfectionism\n\n2022-02-04\n\nThere is a common idea that perfectionism is the need for perfect results: the maximum test score, the flawless recital, the unanimous verdict. But this idea misses the deeper reality. More generally, perfectionism is the tendency to stake your identity on achieving fixed outcomes.\n\nFixed outcomes vary by person. The perfect performance is the stereotype, but a fixed outcome might be feeling smart, beautiful, and right, or getting that car or job we\'ve been craving for so long. Every perfectionist has their own personal ideal.\n\nNone of these outcomes are problems. But they become so when they intertwine with our identity and self-worth. If a perfectionist of fame ever feels unknown, then he feels worthless and ashamed.\n\nHence the perfectionist stakes his identity on achieving his outcomes, meaning his self-worth depends on realizing them. This is a pitiful wager and a poor strategy.\n\nAbove all, perfectionism is a tendency, not a law. With practice, we can unlearn it and replace it with far better approaches.\n\nIf you clearly see this tendency in yourself, you then have a choice: to reinforce it through your actions, or to unlearn it and practice something better.\n\nEither way, it\'s your decision.\nII. The tendency\n\nLet\'s first see the tendency clearly. Let\'s enter the mind of a severe perfectionist.\n\nOur perfectionist has always done well in school and has been told that she\'s smart by all of the most important people in her life. Now it\'s just part of how she sees herself. Success affirms who she is as a person.\n\nShe starts her new projects with an optimistic but brittle confidence. Easy tasks and small problems are within her grasp, and she handles them flawlessly. But as the difficulties rise, her confidence falters.\n\nIf the tendency were milder, she could push through. But she wants to preserve her self-image so badly that she refuses to face her imperfect reality.\n\nSo she feels threatened by moderate setbacks and finds any number of excuses to procrastinate: she\'s not in the mood, not in the right place, too busy, not inspired, too hungry, too full, too alert, too tired.\n\nWhen the work is uncertain, she withers: uncertainty means the unknown, which means risk, which means failure, which means she\'s worthless. The thought of fumbling in the void terrifies her. So she retreats into the safe and familiar. She checks her email for the hundredth time.\n\nShe might refuse help of any kind. She might procrastinate then resort to last-minute heroics. Or she might chase standards that are delusionally high. In a way, her self-sabotage tilts the game in her favor. If she succeeds despite it, she affirms her brilliance and talent. And if she fails, she survives unscathed because nobody else was playing her impossible game, which means nobody can make her feel inferior.\n\nIn the worst case, she intentionally fails: better, she thinks, to crash and burn than be mistaken for someone mediocre.\n\nShe tirelessly finds excuses to ward off her rising anxiety: the project would be difficult for anyone, or only a genius could figure it out, or she never really cared about it anyway, or the work is simply beneath her. At her lowest she blames others: everything would be fine if it weren\'t for them.\n\nWhen others surpass her, her dynamics are no different. They have more money, better connections, savvier teachers, richer opportunities ... the game was rigged from the start. At her most primitive, she seethes: they may be more intelligent, but at least she\'s a deeper thinker, a more ethical human being.\n\nSelf-awareness is no balm and becomes part of her defense: she knows how she is, sure, but it\'s just her personality, or it\'s the fault of her upbringing, or she\'s just an idealist, or she\'s sagely accepting herself as she is.\n\nBecause she has the tendency, she can justify not changing; therefore she chooses and reinforces it. It becomes both cause and effect. ...

# %% [markdown]
# ## Normalization

# %%
normalized_text = text.lower()
normalized_text = re.sub(r'[^a-z\s]', '', normalized_text)
normalized_text = re.sub(r'\s+', ' ', normalized_text)
normalized_text = normalized_text.strip()
normalized_text
# Out:
# 'unlearning perfectionism there is a common idea that perfectionism is the need for perfect results the maximum test score the flawless recital the unanimous verdict but this idea misses the deeper reality more generally perfectionism is the tendency to stake your identity on achieving fixed outcomes fixed outcomes vary by person the perfect performance is the stereotype but a fixed outcome might be feeling smart beautiful and right or getting that car or job weve been craving for so long every perfectionist has their own personal ideal none of these outcomes are problems but they become so when they intertwine with our identity and selfworth if a perfectionist of fame ever feels unknown then he feels worthless and ashamed hence the perfectionist stakes his identity on achieving his outcomes meaning his selfworth depends on realizing them this is a pitiful wager and a poor strategy above all perfectionism is a tendency not a law with practice we can unlearn it and replace it with far better approaches if you clearly see this tendency in yourself you then have a choice to reinforce it through your actions or to unlearn it and practice something better either way its your decision ii the tendency lets first see the tendency clearly lets enter the mind of a severe perfectionist our perfectionist has always done well in school and has been told that shes smart by all of the most important people in her life now its just part of how she sees herself success affirms who she is as a person she starts her new projects with an optimistic but brittle confidence easy tasks and small problems are within her grasp and she handles them flawlessly but as the difficulties rise her confidence falters if the tendency were milder she could push through but she wants to preserve her selfimage so badly that she refuses to face her imperfect reality so she feels threatened by moderate setbacks and finds any number of excuses to procrastinate shes not in the mood not in the right place too busy not inspired too hungry too full too alert too tired when the work is uncertain she withers uncertainty means the unknown which means risk which means failure which means shes worthless the thought of fumbling in the void terrifies her so she retreats into the safe and familiar she checks her email for the hundredth time she might refuse help of any kind she might procrastinate then resort to lastminute heroics or she might chase standards that are delusionally high in a way her selfsabotage tilts the game in her favor if she succeeds despite it she affirms her brilliance and talent and if she fails she survives unscathed because nobody else was playing her impossible game which means nobody can make her feel inferior in the worst case she intentionally fails better she thinks to crash and burn than be mistaken for someone mediocre she tirelessly finds excuses to ward off her rising anxiety the project would be difficult for anyone or only a genius could figure it out or she never really cared about it anyway or the work is simply beneath her at her lowest she blames others everything would be fine if it werent for them when others surpass her her dynamics are no different they have more money better connections savvier teachers richer opportunities the game was rigged from the start at her most primitive she seethes they may be more intelligent but at least shes a deeper thinker a more ethical human being selfawareness is no balm and becomes part of her defense she knows how she is sure but its just her personality or its the fault of her upbringing or shes just an idealist or shes sagely accepting herself as she is because she has the tendency she can justify not changing therefore she chooses and reinforces it it becomes both cause and effect what she wont do and cant do is take action and try with the whole of her being since nothing would be more excruciating than to do so and fail anyway or if she must try her effort is woven through with her frustratio ...

# %% [markdown]
# ## Tokenization

# %%
sent_tokens = sent_tokenize(text)
sent_tokens
# Out:
# ['Unlearning Perfectionism\n\n2022-02-04\n\nThere is a common idea that perfectionism is the need for perfect results: the maximum test score, the flawless recital, the unanimous verdict.',
#  'But this idea misses the deeper reality.',
#  'More generally, perfectionism is the tendency to stake your identity on achieving fixed outcomes.',
#  'Fixed outcomes vary by person.',
#  "The perfect performance is the stereotype, but a fixed outcome might be feeling smart, beautiful, and right, or getting that car or job we've been craving for so long.",
#  'Every perfectionist has their own personal ideal.',
#  'None of these outcomes are problems.',
#  'But they become so when they intertwine with our identity and self-worth.',
#  'If a perfectionist of fame ever feels unknown, then he feels worthless and ashamed.',
#  'Hence the perfectionist stakes his identity on achieving his outcomes, meaning his self-worth depends on realizing them.',
#  'This is a pitiful wager and a poor strategy.',
#  'Above all, perfectionism is a tendency, not a law.',
#  'With practice, we can unlearn it and replace it with far better approaches.',
#  'If you clearly see this tendency in yourself, you then have a choice: to reinforce it through your actions, or to unlearn it and practice something better.',
#  "Either way, it's your decision.",
#  'II.',
#  "The tendency\n\nLet's first see the tendency clearly.",
#  "Let's enter the mind of a severe perfectionist.",
#  "Our perfectionist has always done well in school and has been told that she's smart by all of the most important people in her life.",
#  "Now it's just part of how she sees herself.",
#  'Success affirms who she is as a person.',
#  'She starts her new projects with an optimistic but brittle confidence.',
#  'Easy tasks and small problems are within her grasp, and she handles them flawlessly.',
#  'But as the difficulties rise, her confidence falters.',
#  'If the tendency were milder, she could push through.',
#  'But she wants to preserve her self-image so badly that she refuses to face her imperfect reality.',
#  "So she feels threatened by moderate setbacks and finds any number of excuses to procrastinate: she's not in the mood, not in the right place, too busy, not inspired, too hungry, too full, too alert, too tired.",
#  "When the work is uncertain, she withers: uncertainty means the unknown, which means risk, which means failure, which means she's worthless.",
#  'The thought of fumbling in the void terrifies her.',
#  'So she retreats into the safe and familiar.',
#  'She checks her email for the hundredth time.',
#  'She might refuse help of any kind.',
#  'She might procrastinate then resort to last-minute heroics.',
#  'Or she might chase standards that are delusionally high.',
#  'In a way, her self-sabotage tilts the game in her favor.',
#  'If she succeeds despite it, she affirms her brilliance and talent.',
#  'And if she fails, she survives unscathed because nobody else was playing her impossible game, which means nobody can make her feel inferior.',
#  'In the worst case, she intentionally fails: better, she thinks, to crash and burn than be mistaken for someone mediocre.',
#  'She tirelessly finds excuses to ward off her rising anxiety: the project would be difficult for anyone, or only a genius could figure it out, or she never really cared about it anyway, or the work is simply beneath her.',
#  "At her lowest she blames others: everything would be fine if it weren't for them.",
#  'When others surpass her, her dynamics are no different.',
#  'They have more money, better connections, savvier teachers, richer opportunities ... the game was rigged from the start.',
#  "At her most primitive, she seethes: they may be more intelligent, but at least she's a deeper thinker, a more ethical human being.",
#  "Self-awareness is no balm and becomes part of her defense: she knows how she is, sure, but it's just her personality, or it's the fault of her upbringing, or she's just an idealist, or she's sagely accepting herself as she is.",
#  'Because she has the tendency, she can justify not changing; therefore she chooses and reinforces it.',
#  'It becomes both cause and effect.',
#  "What she won't do — and can't do — is take action and try with the whole of her being, since nothing would be more excruciating than to do so and fail anyway.",
#  'Or if she must try, her effort is woven through with her frustration and shame.',
#  'If shorn of her defenses, she suffers existentially: she wagered her self-worth, and she lost.',
#  'She berates herself — "Why am I so stupid?',
#  'Why can\'t I be better?"',
#  '— and copes with the bitter result.',
#  'And if the failure is more than she can handle, she feels irrevocably worthless and enters deeper hells I cannot name.',
#  'All of her excuses are valid in the right context.',
#  "That's what makes them such good cover.",
#  'But the tell is what comes next.',
#  '"It\'s just my personality" — therefore, what?',
#  "And the response: therefore, she doesn't need to change.",
#  "The perfectionist fears setbacks, uncertainty, true knowledge of her strengths and weaknesses, failure that can't be blamed on others, and anything else that threatens her outcomes or her fixed sense of self.",
#  'She deprives herself of the explosive growth that comes from uncertainty, struggle, and open exploration.',
#  'Like a tree that grows only as large as its pot, she hews to the familiar and stunts her potential.',
#  'She is theory over practice; dreaming over acting; resentment over curiosity; fantasy over reality.',
#  'She dwells in puddles for fear of the ocean.',
#  'III.',
#  'Pro and contra\n\nPerfectionism endures because it has its merits, and we must see these clearly as well.',
#  'It establishes a high standard and feeds on a source of intense energy, i.e.',
#  'the fear of losing our identity and self-worth.',
#  "So it is no surprise that some of the world's luminaries have made contracts with it.",
#  'But the cost of that contract is just as present.',
#  'Carl Gauss, through whom it set mathematics back by decades:\n\n    His own contemporaries begged him to relax his frigid perfection so that mathematics might advance more rapidly, but Gauss never relaxed.',
#  '[...] Had he divulged what he knew it is quite possible that mathematics would now be half a century or more ahead of where it is.',
#  '— E.T.',
#  'Bell, Men of Mathematics\n\nVirgil, through whom it almost deprived the world of a masterpiece:\n\n    In his last illness he called for the cases containing his manuscripts, with the intention of burning the Aeneid.',
#  '[...] [H]e speaks as if he felt that the undertaking of the work had been a mistake.',
#  'This dissatisfaction with his work may be ascribed to his passion for perfection of workmanship, which death prevented him from attaining.',
#  '— 1911 Encyclopedia Brittanica\n\nBill Walsh, whose coaching career it utterly destroyed:\n\n    He would sit dazed in his hot tub even after wins, despondent that he had miscalculated a play or two.',
#  '"I was a tortured person," Walsh later told biographer Harris.',
#  '"I felt the failure so personally ... eventually I couldn\'t get out from under it all.',
#  "You can't live that way long.",
#  'You can only attack that part of your nervous system so many times."',
#  '— Seth Wickersham, "The Book of Coach"\n\nI\'m not anywhere near the level of these people, and I have no right to tell them to live differently.',
#  'But I shudder to think of how much farther they could have gone had they only practiced a better approach.',
#  'More prosaically, the tendency correlates with a stunning number of maladaptive patterns, often as a cause.',
#  'Here are four:\n\n    Procrastination through fear of failure and delaying complex uncertain tasks.',
#  'The perfectionist procrastinates to avoid confronting her imperfection.',
#  "She is also slow to ask for help because doing so would mean admitting that she's struggling.",
#  'Impostor syndrome as the fear of being found out and judged unworthy: not smart, not capable, not good enough to meet an ideal standard.',
#  'The perfectionist blends in and acts the part for fear of being found out and rejected.',
#  'Obsessive compulsion, both as full OCD and in its milder forms.',
#  'For example, the recurring anxious fear of inadequacy leads to the self-soothing response of scrolling Twitter for an hour.',
#  'Burnout, which some see as a kind of PTSD.',
#  'A defenseless perfectionist that chronically fails to live up to her ideal endures deep emotional trauma.',
#  'In the worst case, she loses all sense of self-worth.',
#  'Perfectionism might restrict itself to just one domain.',
#  'But our core tendencies tend to cut across all the realms of life.',
#  'It is this quality that makes them so valuable, or so insidious.',
#  'IV.',
#  'An alternative\n\nMuch of perfectionism is what we learn as children and choose as adults.',
#  "To the extent that we choose it, it is a fool's choice that we can unlearn.",
#  'But if not perfectionism, then what?',
#  'One alternative with a similar flavor is excellence, which differs in two respects:\n\n    Where perfectionism focuses on achieving, excellence focuses on pursuing.',
#  "Success and failure aren't ever in our full control.",
#  'All we can control is what we choose to do right now, in this moment.',
#  'Our attention shifts from outcomes to process.',
#  'Where perfectionism focuses on fixed outcomes, excellence focuses on better outcomes.',
#  'Any real situation can always be improved.',
#  'Since there is no perfect outcome, perfection is impossible.',
#  "Let's see this tendency clearly and revisit our perfectionist from earlier.",
#  'Our former perfectionist prides herself on working hard and paying attention to what she does.',
#  'Just by being present, she feels great satisfaction.',
#  'She starts her new projects with a steady confidence that endures regardless of the difficulties underfoot.',
#  'When the work is uncertain, she persists: uncertainty and the unknown are no longer a threat to her, and no matter where she is, she just focuses on taking the next step.',
#  'Since she embraces imperfection, she gives a sincere effort regardless of how motivated she feels.',
#  "Life's little difficulties are not enough to deter her.",
#  'If the project is hard enough, setbacks and failures are inevitable.',
#  'But she learns so much from them that she treats them like precious friends.',
#  "While they aren't exactly pleasant, they show where she can improve and grow.",
#  "If she hasn't failed recently, she knows that she's playing too safe.",
#  'When she feels stuck, she has no problem asking for help and advice.',
#  'She may feel the usual anxieties and stresses of a big project, but such worries are no longer self-inflicted.',
#  'In general, she is serene and steady.',
#  'And when she feels that her work is good enough, she completes it and moves on.',
#  'When others achieve better outcomes than her, she responds with openness and curiosity.',
#  'If there is something she can learn from them, she gladly absorbs the lesson.',
#  'If not, she has no ill-will for them.',
#  'She focuses on what she can control: the pursuit, not the outcome.',
#  'In doing so, she opts out of the comparison game.',
#  'She is always rooted in the reality of the moment.',
#  'Process over outcomes; systems over goals; growth mindset over fixed mindset; satisficing over maximizing; professionalism over amateurism; boring fundamentals over flashy tricks; response over reaction; agency over passivity; presence over regret and worry.',
#  'No matter what you call it, the distinction is the same.',
#  "I don't claim getting here is easy, and I am hardly an expert of it.",
#  'But it is possible if you put in the work.',
#  'And with enough time and practice, it becomes more and more automatic.',
#  'V. A way out\n\nIt is a cruel paradox that the preconditions for meaningful change — wanting to change, believing that change is possible, and committing to regular practice — all run against the tendency itself.',
#  'But with enough self-insight or enough self-inflicted suffering, the perfectionist can arrive here.',
#  'Broadly speaking, the way out has three parts.',
#  'The first is to train the mind to see and endure an imperfect reality.',
#  'The psychological literature recommends various treatment options depending on the situation, but here are three:\n\n    Cognitive-behavioral therapy, which trains the mind to challenge distorted thoughts related to perfectionism (e.g.',
#  '"I\'m a failure" → "I might fail, but I\'m successful in other ways").',
#  'Exposure and response prevention, which trains the mind to tolerate and reduce mental distress by repeatedly facing the distressing thought (e.g.',
#  '"I\'m going to fail" → "Yes, maybe I will.").',
#  'Mindfulness meditation, which trains the mind to engage with thoughts non-reactively (e.g.',
#  '"I\'m going to fail" → "The thought of failure is arising").',
#  'The second is to train the mind to change its stores of self-worth by practicing self-compassion.',
#  'Daily gratitude journaling is a simple place to start.',
#  'The third is to practice the alternative and make it habitual.',
#  'Deeply learned habits must be deeply unlearned, which means practicing the alternative as often as we can.',
#  'Mindfulness meditation can help build the meta-awareness necessary to do so.',
#  'At first, all of these may feel unnatural and fake.',
#  'Progress may be slow enough that the training feels useless.',
#  'But you must persist.',
#  'A trusted friend, a mentor, or a therapist can help keep you accountable.',
#  "Here are specific resources you can use to take the next step:\n\n    A classic book on cognitive-behavioral therapy\n    A basic meditation guide from the New York Times\n    A gratitude journaling guide from UC Berkeley\n\nTo the perfectionists reading this: I've been around the internet for a while, and it grieves me that I know what most of you will do next.",
#  'What most of you will do is nothing.',
#  'So here is something concrete you can do right now.',
#  'Write me an email at <my_first_name>90 at gmail.',
#  'Set a timer for 5 minutes, and write as little or as much as you want.',
#  'And when your time is up, send it out.',
#  'One small act of stepping into the unknown.',
#  "As simple as it sounds, that is the only way out, and that's all it takes to get started."]

# %%
word_tokens = word_tokenize(normalized_text)
word_tokens
# Out:
# ['unlearning',
#  'perfectionism',
#  'there',
#  'is',
#  'a',
#  'common',
#  'idea',
#  'that',
#  'perfectionism',
#  'is',
#  'the',
#  'need',
#  'for',
#  'perfect',
#  'results',
#  'the',
#  'maximum',
#  'test',
#  'score',
#  'the',
#  'flawless',
#  'recital',
#  'the',
#  'unanimous',
#  'verdict',
#  'but',
#  'this',
#  'idea',
#  'misses',
#  'the',
#  'deeper',
#  'reality',
#  'more',
#  'generally',
#  'perfectionism',
#  'is',
#  'the',
#  'tendency',
#  'to',
#  'stake',
#  'your',
#  'identity',
#  'on',
#  'achieving',
#  'fixed',
#  'outcomes',
#  'fixed',
#  'outcomes',
#  'vary',
#  'by',
#  'person',
#  'the',
#  'perfect',
#  'performance',
#  'is',
#  'the',
#  'stereotype',
#  'but',
#  'a',
#  'fixed',
#  'outcome',
#  'might',
#  'be',
#  'feeling',
#  'smart',
#  'beautiful',
#  'and',
#  'right',
#  'or',
#  'getting',
#  'that',
#  'car',
#  'or',
#  'job',
#  'weve',
#  'been',
#  'craving',
#  'for',
#  'so',
#  'long',
#  'every',
#  'perfectionist',
#  'has',
#  'their',
#  'own',
#  'personal',
#  'ideal',
#  'none',
#  'of',
#  'these',
#  'outcomes',
#  'are',
#  'problems',
#  'but',
#  'they',
#  'become',
#  'so',
#  'when',
#  'they',
#  'intertwine',
#  'with',
#  'our',
#  'identity',
#  'and',
#  'selfworth',
#  'if',
#  'a',
#  'perfectionist',
#  'of',
#  'fame',
#  'ever',
#  'feels',
#  'unknown',
#  'then',
#  'he',
#  'feels',
#  'worthless',
#  'and',
#  'ashamed',
#  'hence',
#  'the',
#  'perfectionist',
#  'stakes',
#  'his',
#  'identity',
#  'on',
#  'achieving',
#  'his',
#  'outcomes',
#  'meaning',
#  'his',
#  'selfworth',
#  'depends',
#  'on',
#  'realizing',
#  'them',
#  'this',
#  'is',
#  'a',
#  'pitiful',
#  'wager',
#  'and',
#  'a',
#  'poor',
#  'strategy',
#  'above',
#  'all',
#  'perfectionism',
#  'is',
#  'a',
#  'tendency',
#  'not',
#  'a',
#  'law',
#  'with',
#  'practice',
#  'we',
#  'can',
#  'unlearn',
#  'it',
#  'and',
#  'replace',
#  'it',
#  'with',
#  'far',
#  'better',
#  'approaches',
#  'if',
#  'you',
#  'clearly',
#  'see',
#  'this',
#  'tendency',
#  'in',
#  'yourself',
#  'you',
#  'then',
#  'have',
#  'a',
#  'choice',
#  'to',
#  'reinforce',
#  'it',
#  'through',
#  'your',
#  'actions',
#  'or',
#  'to',
#  'unlearn',
#  'it',
#  'and',
#  'practice',
#  'something',
#  'better',
#  'either',
#  'way',
#  'its',
#  'your',
#  'decision',
#  'ii',
#  'the',
#  'tendency',
#  'lets',
#  'first',
#  'see',
#  'the',
#  'tendency',
#  'clearly',
#  'lets',
#  'enter',
#  'the',
#  'mind',
#  'of',
#  'a',
#  'severe',
#  'perfectionist',
#  'our',
#  'perfectionist',
#  'has',
#  'always',
#  'done',
#  'well',
#  'in',
#  'school',
#  'and',
#  'has',
#  'been',
#  'told',
#  'that',
#  'shes',
#  'smart',
#  'by',
#  'all',
#  'of',
#  'the',
#  'most',
#  'important',
#  'people',
#  'in',
#  'her',
#  'life',
#  'now',
#  'its',
#  'just',
#  'part',
#  'of',
#  'how',
#  'she',
#  'sees',
#  'herself',
#  'success',
#  'affirms',
#  'who',
#  'she',
#  'is',
#  'as',
#  'a',
#  'person',
#  'she',
#  'starts',
#  'her',
#  'new',
#  'projects',
#  'with',
#  'an',
#  'optimistic',
#  'but',
#  'brittle',
#  'confidence',
#  'easy',
#  'tasks',
#  'and',
#  'small',
#  'problems',
#  'are',
#  'within',
#  'her',
#  'grasp',
#  'and',
#  'she',
#  'handles',
#  'them',
#  'flawlessly',
#  'but',
#  'as',
#  'the',
#  'difficulties',
#  'rise',
#  'her',
#  'confidence',
#  'falters',
#  'if',
#  'the',
#  'tendency',
#  'were',
#  'milder',
#  'she',
#  'could',
#  'push',
#  'through',
#  'but',
#  'she',
#  'wants',
#  'to',
#  'preserve',
#  'her',
#  'selfimage',
#  'so',
#  'badly',
#  'that',
#  'she',
#  'refuses',
#  'to',
#  'face',
#  'her',
#  'imperfect',
#  'reality',
#  'so',
#  'she',
#  'feels',
#  'threatened',
#  'by',
#  'moderate',
#  'setbacks',
#  'and',
#  'finds',
#  'any',
#  'number',
#  'of',
#  'excuses',
#  'to',
#  'procrastinate',
#  'shes',
#  'not',
#  'in',
#  'the',
#  'mood',
#  'not',
#  'in',
#  'the',
#  'right',
#  'place',
#  'too',
#  'busy',
#  'not',
#  'inspired',
#  'too',
#  'hungry',
#  'too',
#  'full',
#  'too',
#  'alert',
#  'too',
#  'tired',
#  'when',
#  'the',
#  'work',
#  'is',
#  'uncertain',
#  'she',
#  'withers',
#  'uncertainty',
#  'means',
#  'the',
#  'unknown',
#  'which',
#  'means',
#  'risk',
#  'which',
#  'means',
#  'failure',
#  'which',
#  'means',
#  'shes',
#  'worthless',
#  'the',
#  'thought',
#  'of',
#  'fumbling',
#  'in',
#  'the',
#  'void',
#  'terrifies',
#  'her',
#  'so',
#  'she',
#  'retreats',
#  'into',
#  'the',
#  'safe',
#  'and',
#  'familiar',
#  'she',
#  'checks',
#  'her',
#  'email',
#  'for',
#  'the',
#  'hundredth',
#  'time',
#  'she',
#  'might',
#  'refuse',
#  'help',
#  'of',
#  'any',
#  'kind',
#  'she',
#  'might',
#  'procrastinate',
#  'then',
#  'resort',
#  'to',
#  'lastminute',
#  'heroics',
#  'or',
#  'she',
#  'might',
#  'chase',
#  'standards',
#  'that',
#  'are',
#  'delusionally',
#  'high',
#  'in',
#  'a',
#  'way',
#  'her',
#  'selfsabotage',
#  'tilts',
#  'the',
#  'game',
#  'in',
#  'her',
#  'favor',
#  'if',
#  'she',
#  'succeeds',
#  'despite',
#  'it',
#  'she',
#  'affirms',
#  'her',
#  'brilliance',
#  'and',
#  'talent',
#  'and',
#  'if',
#  'she',
#  'fails',
#  'she',
#  'survives',
#  'unscathed',
#  'because',
#  'nobody',
#  'else',
#  'was',
#  'playing',
#  'her',
#  'impossible',
#  'game',
#  'which',
#  'means',
#  'nobody',
#  'can',
#  'make',
#  'her',
#  'feel',
#  'inferior',
#  'in',
#  'the',
#  'worst',
#  'case',
#  'she',
#  'intentionally',
#  'fails',
#  'better',
#  'she',
#  'thinks',
#  'to',
#  'crash',
#  'and',
#  'burn',
#  'than',
#  'be',
#  'mistaken',
#  'for',
#  'someone',
#  'mediocre',
#  'she',
#  'tirelessly',
#  'finds',
#  'excuses',
#  'to',
#  'ward',
#  'off',
#  'her',
#  'rising',
#  'anxiety',
#  'the',
#  'project',
#  'would',
#  'be',
#  'difficult',
#  'for',
#  'anyone',
#  'or',
#  'only',
#  'a',
#  'genius',
#  'could',
#  'figure',
#  'it',
#  'out',
#  'or',
#  'she',
#  'never',
#  'really',
#  'cared',
#  'about',
#  'it',
#  'anyway',
#  'or',
#  'the',
#  'work',
#  'is',
#  'simply',
#  'beneath',
#  'her',
#  'at',
#  'her',
#  'lowest',
#  'she',
#  'blames',
#  'others',
#  'everything',
#  'would',
#  'be',
#  'fine',
#  'if',
#  'it',
#  'werent',
#  'for',
#  'them',
#  'when',
#  'others',
#  'surpass',
#  'her',
#  'her',
#  'dynamics',
#  'are',
#  'no',
#  'different',
#  'they',
#  'have',
#  'more',
#  'money',
#  'better',
#  'connections',
#  'savvier',
#  'teachers',
#  'richer',
#  'opportunities',
#  'the',
#  'game',
#  'was',
#  'rigged',
#  'from',
#  'the',
#  'start',
#  'at',
#  'her',
#  'most',
#  'primitive',
#  'she',
#  'seethes',
#  'they',
#  'may',
#  'be',
#  'more',
#  'intelligent',
#  'but',
#  'at',
#  'least',
#  'shes',
#  'a',
#  'deeper',
#  'thinker',
#  'a',
#  'more',
#  'ethical',
#  'human',
#  'being',
#  'selfawareness',
#  'is',
#  'no',
#  'balm',
#  'and',
#  'becomes',
#  'part',
#  'of',
#  'her',
#  'defense',
#  'she',
#  'knows',
#  'how',
#  'she',
#  'is',
#  'sure',
#  'but',
#  'its',
#  'just',
#  'her',
#  'personality',
#  'or',
#  'its',
#  'the',
#  'fault',
#  'of',
#  'her',
#  'upbringing',
#  'or',
#  'shes',
#  'just',
#  'an',
#  'idealist',
#  'or',
#  'shes',
#  'sagely',
#  'accepting',
#  'herself',
#  'as',
#  'she',
#  'is',
#  'because',
#  'she',
#  'has',
#  'the',
#  'tendency',
#  'she',
#  'can',
#  'justify',
#  'not',
#  'changing',
#  'therefore',
#  'she',
#  'chooses',
#  'and',
#  'reinforces',
#  'it',
#  'it',
#  'becomes',
#  'both',
#  'cause',
#  'and',
#  'effect',
#  'what',
#  'she',
#  'wont',
#  'do',
#  'and',
#  'cant',
#  'do',
#  'is',
#  'take',
#  'action',
#  'and',
#  'try',
#  'with',
#  'the',
#  'whole',
#  'of',
#  'her',
#  'being',
#  'since',
#  'nothing',
#  'would',
#  'be',
#  'more',
#  'excruciating',
#  'than',
#  'to',
#  'do',
#  'so',
#  'and',
#  'fail',
#  'anyway',
#  'or',
#  'if',
#  'she',
#  'must',
#  'try',
#  'her',
#  'effort',
#  'is',
#  'woven',
#  'through',
#  'with',
#  'her',
#  'frustration',
#  'and',
#  'shame',
#  'if',
#  'shorn',
#  'of',
#  'her',
#  'defenses',
#  'she',
#  'suffers',
#  'existentially',
#  'she',
#  'wagered',
#  'her',
#  'selfworth',
#  'and',
#  'she',
#  'lost',
#  'she',
#  'berates',
#  'herself',
#  'why',
#  'am',
#  'i',
#  'so',
#  'stupid',
#  'why',
#  'cant',
#  'i',
#  'be',
#  'better',
#  'and',
#  'copes',
#  'with',
#  'the',
#  'bitter',
#  'result',
#  'and',
#  'if',
#  'the',
#  'failure',
#  'is',
#  'more',
#  'than',
#  'she',
#  'can',
#  'handle',
#  'she',
#  'feels',
#  'irrevocably',
#  'worthless',
#  'and',
#  'enters',
#  'deeper',
#  'hells',
#  'i',
#  'can',
#  'not',
#  'name',
#  'all',
#  'of',
#  'her',
#  'excuses',
#  'are',
#  'valid',
#  'in',
#  'the',
#  'right',
#  'context',
#  'thats',
#  'what',
#  'makes',
#  'them',
#  'such',
#  'good',
#  'cover',
#  'but',
#  'the',
#  'tell',
#  'is',
#  'what',
#  'comes',
#  'next',
#  'its',
#  'just',
#  'my',
#  'personality',
#  'therefore',
#  'what',
#  'and',
#  'the',
#  'response',
#  'therefore',
#  'she',
#  'doesnt',
#  'need',
#  'to',
#  'change',
#  'the',
#  'perfectionist',
#  'fears',
#  'setbacks',
#  'uncertainty',
#  'true',
#  'knowledge',
#  'of',
#  'her',
#  'strengths',
#  'and',
#  'weaknesses',
#  'failure',
#  'that',
#  'cant',
#  'be',
#  'blamed',
#  'on',
#  'others',
#  'and',
#  'anything',
#  'else',
#  'that',
#  'threatens',
#  'her',
#  'outcomes',
#  'or',
#  'her',
#  'fixed',
#  'sense',
#  'of',
#  'self',
#  'she',
#  'deprives',
#  'herself',
#  'of',
#  'the',
#  'explosive',
#  'growth',
#  'that',
#  'comes',
#  'from',
#  'uncertainty',
#  'struggle',
#  'and',
#  'open',
#  'exploration',
#  'like',
#  'a',
#  'tree',
#  'that',
#  'grows',
#  'only',
#  'as',
#  'large',
#  'as',
#  'its',
#  'pot',
#  'she',
#  'hews',
#  'to',
#  'the',
#  'familiar',
#  'and',
#  'stunts',
#  'her',
#  'potential',
#  'she',
#  'is',
#  'theory',
#  'over',
#  'practice',
#  'dreaming',
#  'over',
#  'acting',
#  'resentment',
#  'over',
#  'curiosity',
#  'fantasy',
#  'over',
#  'reality',
#  'she',
#  'dwells',
#  'in',
#  'puddles',
#  'for',
#  'fear',
#  'of',
#  'the',
#  'ocean',
#  'iii',
#  'pro',
#  'and',
#  'contra',
#  'perfectionism',
#  'endures',
#  'because',
#  'it',
#  'has',
#  'its',
#  'merits',
#  'and',
#  'we',
#  'must',
#  'see',
#  'these',
#  'clearly',
#  'as',
#  'well',
#  'it',
#  'establishes',
#  'a',
#  'high',
#  'standard',
#  'and',
#  'feeds',
#  'on',
#  'a',
#  'source',
#  'of',
#  'intense',
#  'energy',
#  'ie',
#  'the',
#  'fear',
#  'of',
#  'losing',
#  'our',
#  'identity',
#  'and',
#  'selfworth',
#  'so',
#  'it',
#  'is',
#  'no',
#  'surprise',
#  'that',
#  'some',
#  'of',
#  'the',
#  'worlds',
#  'luminaries',
#  'have',
#  'made',
#  'contracts',
#  'with',
#  'it',
#  'but',
#  'the',
#  'cost',
#  'of',
#  'that',
#  'contract',
#  'is',
#  'just',
#  'as',
#  'present',
#  'carl',
#  'gauss',
#  'through',
#  'whom',
#  'it',
#  'set',
#  'mathematics',
#  'back',
#  'by',
#  'decades',
#  'his',
#  'own',
#  'contemporaries',
#  'begged',
#  'him',
#  'to',
#  'relax',
#  'his',
#  'frigid',
#  'perfection',
#  'so',
#  'that',
#  'mathematics',
#  'might',
#  'advance',
#  'more',
#  'rapidly',
#  'but',
#  'gauss',
#  'never',
#  'relaxed',
#  'had',
#  'he',
#  'divulged',
#  'what',
#  'he',
#  'knew',
#  'it',
#  'is',
#  'quite',
#  'possible',
#  'that',
#  'mathematics',
#  'would',
#  'now',
#  'be',
#  ...]

# %% [markdown]
# ## Stop-Word Removal

# %%
stop_words = set(stopwords.words('english'))
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
filtered_words = [w for w in word_tokens if w not in stop_words]
filtered_words
# Out:
# ['unlearning',
#  'perfectionism',
#  'common',
#  'idea',
#  'perfectionism',
#  'need',
#  'perfect',
#  'results',
#  'maximum',
#  'test',
#  'score',
#  'flawless',
#  'recital',
#  'unanimous',
#  'verdict',
#  'idea',
#  'misses',
#  'deeper',
#  'reality',
#  'generally',
#  'perfectionism',
#  'tendency',
#  'stake',
#  'identity',
#  'achieving',
#  'fixed',
#  'outcomes',
#  'fixed',
#  'outcomes',
#  'vary',
#  'person',
#  'perfect',
#  'performance',
#  'stereotype',
#  'fixed',
#  'outcome',
#  'might',
#  'feeling',
#  'smart',
#  'beautiful',
#  'right',
#  'getting',
#  'car',
#  'job',
#  'weve',
#  'craving',
#  'long',
#  'every',
#  'perfectionist',
#  'personal',
#  'ideal',
#  'none',
#  'outcomes',
#  'problems',
#  'become',
#  'intertwine',
#  'identity',
#  'selfworth',
#  'perfectionist',
#  'fame',
#  'ever',
#  'feels',
#  'unknown',
#  'feels',
#  'worthless',
#  'ashamed',
#  'hence',
#  'perfectionist',
#  'stakes',
#  'identity',
#  'achieving',
#  'outcomes',
#  'meaning',
#  'selfworth',
#  'depends',
#  'realizing',
#  'pitiful',
#  'wager',
#  'poor',
#  'strategy',
#  'perfectionism',
#  'tendency',
#  'law',
#  'practice',
#  'unlearn',
#  'replace',
#  'far',
#  'better',
#  'approaches',
#  'clearly',
#  'see',
#  'tendency',
#  'choice',
#  'reinforce',
#  'actions',
#  'unlearn',
#  'practice',
#  'something',
#  'better',
#  'either',
#  'way',
#  'decision',
#  'ii',
#  'tendency',
#  'lets',
#  'first',
#  'see',
#  'tendency',
#  'clearly',
#  'lets',
#  'enter',
#  'mind',
#  'severe',
#  'perfectionist',
#  'perfectionist',
#  'always',
#  'done',
#  'well',
#  'school',
#  'told',
#  'shes',
#  'smart',
#  'important',
#  'people',
#  'life',
#  'part',
#  'sees',
#  'success',
#  'affirms',
#  'person',
#  'starts',
#  'new',
#  'projects',
#  'optimistic',
#  'brittle',
#  'confidence',
#  'easy',
#  'tasks',
#  'small',
#  'problems',
#  'within',
#  'grasp',
#  'handles',
#  'flawlessly',
#  'difficulties',
#  'rise',
#  'confidence',
#  'falters',
#  'tendency',
#  'milder',
#  'could',
#  'push',
#  'wants',
#  'preserve',
#  'selfimage',
#  'badly',
#  'refuses',
#  'face',
#  'imperfect',
#  'reality',
#  'feels',
#  'threatened',
#  'moderate',
#  'setbacks',
#  'finds',
#  'number',
#  'excuses',
#  'procrastinate',
#  'shes',
#  'mood',
#  'right',
#  'place',
#  'busy',
#  'inspired',
#  'hungry',
#  'full',
#  'alert',
#  'tired',
#  'work',
#  'uncertain',
#  'withers',
#  'uncertainty',
#  'means',
#  'unknown',
#  'means',
#  'risk',
#  'means',
#  'failure',
#  'means',
#  'shes',
#  'worthless',
#  'thought',
#  'fumbling',
#  'void',
#  'terrifies',
#  'retreats',
#  'safe',
#  'familiar',
#  'checks',
#  'email',
#  'hundredth',
#  'time',
#  'might',
#  'refuse',
#  'help',
#  'kind',
#  'might',
#  'procrastinate',
#  'resort',
#  'lastminute',
#  'heroics',
#  'might',
#  'chase',
#  'standards',
#  'delusionally',
#  'high',
#  'way',
#  'selfsabotage',
#  'tilts',
#  'game',
#  'favor',
#  'succeeds',
#  'despite',
#  'affirms',
#  'brilliance',
#  'talent',
#  'fails',
#  'survives',
#  'unscathed',
#  'nobody',
#  'else',
#  'playing',
#  'impossible',
#  'game',
#  'means',
#  'nobody',
#  'make',
#  'feel',
#  'inferior',
#  'worst',
#  'case',
#  'intentionally',
#  'fails',
#  'better',
#  'thinks',
#  'crash',
#  'burn',
#  'mistaken',
#  'someone',
#  'mediocre',
#  'tirelessly',
#  'finds',
#  'excuses',
#  'ward',
#  'rising',
#  'anxiety',
#  'project',
#  'would',
#  'difficult',
#  'anyone',
#  'genius',
#  'could',
#  'figure',
#  'never',
#  'really',
#  'cared',
#  'anyway',
#  'work',
#  'simply',
#  'beneath',
#  'lowest',
#  'blames',
#  'others',
#  'everything',
#  'would',
#  'fine',
#  'werent',
#  'others',
#  'surpass',
#  'dynamics',
#  'different',
#  'money',
#  'better',
#  'connections',
#  'savvier',
#  'teachers',
#  'richer',
#  'opportunities',
#  'game',
#  'rigged',
#  'start',
#  'primitive',
#  'seethes',
#  'may',
#  'intelligent',
#  'least',
#  'shes',
#  'deeper',
#  'thinker',
#  'ethical',
#  'human',
#  'selfawareness',
#  'balm',
#  'becomes',
#  'part',
#  'defense',
#  'knows',
#  'sure',
#  'personality',
#  'fault',
#  'upbringing',
#  'shes',
#  'idealist',
#  'shes',
#  'sagely',
#  'accepting',
#  'tendency',
#  'justify',
#  'changing',
#  'therefore',
#  'chooses',
#  'reinforces',
#  'becomes',
#  'cause',
#  'effect',
#  'wont',
#  'cant',
#  'take',
#  'action',
#  'try',
#  'whole',
#  'since',
#  'nothing',
#  'would',
#  'excruciating',
#  'fail',
#  'anyway',
#  'must',
#  'try',
#  'effort',
#  'woven',
#  'frustration',
#  'shame',
#  'shorn',
#  'defenses',
#  'suffers',
#  'existentially',
#  'wagered',
#  'selfworth',
#  'lost',
#  'berates',
#  'stupid',
#  'cant',
#  'better',
#  'copes',
#  'bitter',
#  'result',
#  'failure',
#  'handle',
#  'feels',
#  'irrevocably',
#  'worthless',
#  'enters',
#  'deeper',
#  'hells',
#  'name',
#  'excuses',
#  'valid',
#  'right',
#  'context',
#  'thats',
#  'makes',
#  'good',
#  'cover',
#  'tell',
#  'comes',
#  'next',
#  'personality',
#  'therefore',
#  'response',
#  'therefore',
#  'doesnt',
#  'need',
#  'change',
#  'perfectionist',
#  'fears',
#  'setbacks',
#  'uncertainty',
#  'true',
#  'knowledge',
#  'strengths',
#  'weaknesses',
#  'failure',
#  'cant',
#  'blamed',
#  'others',
#  'anything',
#  'else',
#  'threatens',
#  'outcomes',
#  'fixed',
#  'sense',
#  'self',
#  'deprives',
#  'explosive',
#  'growth',
#  'comes',
#  'uncertainty',
#  'struggle',
#  'open',
#  'exploration',
#  'like',
#  'tree',
#  'grows',
#  'large',
#  'pot',
#  'hews',
#  'familiar',
#  'stunts',
#  'potential',
#  'theory',
#  'practice',
#  'dreaming',
#  'acting',
#  'resentment',
#  'curiosity',
#  'fantasy',
#  'reality',
#  'dwells',
#  'puddles',
#  'fear',
#  'ocean',
#  'iii',
#  'pro',
#  'contra',
#  'perfectionism',
#  'endures',
#  'merits',
#  'must',
#  'see',
#  'clearly',
#  'well',
#  'establishes',
#  'high',
#  'standard',
#  'feeds',
#  'source',
#  'intense',
#  'energy',
#  'ie',
#  'fear',
#  'losing',
#  'identity',
#  'selfworth',
#  'surprise',
#  'worlds',
#  'luminaries',
#  'made',
#  'contracts',
#  'cost',
#  'contract',
#  'present',
#  'carl',
#  'gauss',
#  'set',
#  'mathematics',
#  'back',
#  'decades',
#  'contemporaries',
#  'begged',
#  'relax',
#  'frigid',
#  'perfection',
#  'mathematics',
#  'might',
#  'advance',
#  'rapidly',
#  'gauss',
#  'never',
#  'relaxed',
#  'divulged',
#  'knew',
#  'quite',
#  'possible',
#  'mathematics',
#  'would',
#  'half',
#  'century',
#  'ahead',
#  'et',
#  'bell',
#  'men',
#  'mathematics',
#  'virgil',
#  'almost',
#  'deprived',
#  'world',
#  'masterpiece',
#  'last',
#  'illness',
#  'called',
#  'cases',
#  'containing',
#  'manuscripts',
#  'intention',
#  'burning',
#  'aeneid',
#  'speaks',
#  'felt',
#  'undertaking',
#  'work',
#  'mistake',
#  'dissatisfaction',
#  'work',
#  'may',
#  'ascribed',
#  'passion',
#  'perfection',
#  'workmanship',
#  'death',
#  'prevented',
#  'attaining',
#  'encyclopedia',
#  'brittanica',
#  'bill',
#  'walsh',
#  'whose',
#  'coaching',
#  'career',
#  'utterly',
#  'destroyed',
#  'would',
#  'sit',
#  'dazed',
#  'hot',
#  'tub',
#  'even',
#  'wins',
#  'despondent',
#  'miscalculated',
#  'play',
#  'two',
#  'tortured',
#  'person',
#  'walsh',
#  'later',
#  'told',
#  'biographer',
#  'harris',
#  'felt',
#  'failure',
#  'personally',
#  'eventually',
#  'couldnt',
#  'get',
#  'cant',
#  'live',
#  'way',
#  'long',
#  'attack',
#  'part',
#  'nervous',
#  'system',
#  'many',
#  'times',
#  'seth',
#  'wickersham',
#  'book',
#  'coach',
#  'im',
#  'anywhere',
#  'near',
#  'level',
#  'people',
#  'right',
#  'tell',
#  'live',
#  'differently',
#  'shudder',
#  'think',
#  'much',
#  'farther',
#  'could',
#  'gone',
#  'practiced',
#  'better',
#  'approach',
#  'prosaically',
#  'tendency',
#  'correlates',
#  'stunning',
#  'number',
#  'maladaptive',
#  'patterns',
#  'often',
#  'cause',
#  'four',
#  'procrastination',
#  'fear',
#  'failure',
#  'delaying',
#  'complex',
#  'uncertain',
#  'tasks',
#  'perfectionist',
#  'procrastinates',
#  'avoid',
#  'confronting',
#  'imperfection',
#  'also',
#  'slow',
#  'ask',
#  'help',
#  'would',
#  'mean',
#  'admitting',
#  'shes',
#  'struggling',
#  'impostor',
#  'syndrome',
#  'fear',
#  'found',
#  'judged',
#  'unworthy',
#  'smart',
#  'capable',
#  'good',
#  'enough',
#  'meet',
#  'ideal',
#  'standard',
#  'perfectionist',
#  'blends',
#  'acts',
#  'part',
#  'fear',
#  'found',
#  'rejected',
#  'obsessive',
#  'compulsion',
#  'full',
#  'ocd',
#  'milder',
#  'forms',
#  'example',
#  'recurring',
#  'anxious',
#  'fear',
#  'inadequacy',
#  'leads',
#  'selfsoothing',
#  'response',
#  'scrolling',
#  'twitter',
#  'hour',
#  'burnout',
#  'see',
#  'kind',
#  'ptsd',
#  'defenseless',
#  'perfectionist',
#  'chronically',
#  'fails',
#  'live',
#  'ideal',
#  'endures',
#  'deep',
#  'emotional',
#  'trauma',
#  'worst',
#  'case',
#  'loses',
#  'sense',
#  'selfworth',
#  'perfectionism',
#  'might',
#  'restrict',
#  'one',
#  'domain',
#  'core',
#  'tendencies',
#  'tend',
#  'cut',
#  'across',
#  'realms',
#  'life',
#  'quality',
#  'makes',
#  'valuable',
#  'insidious',
#  'iv',
#  'alternative',
#  'much',
#  'perfectionism',
#  'learn',
#  'children',
#  'choose',
#  'adults',
#  'extent',
#  'choose',
#  'fools',
#  'choice',
#  'unlearn',
#  'perfectionism',
#  'one',
#  'alternative',
#  'similar',
#  'flavor',
#  'excellence',
#  'differs',
#  'two',
#  'respects',
#  'perfectionism',
#  'focuses',
#  'achieving',
#  'excellence',
#  'focuses',
#  'pursuing',
#  'success',
#  'failure',
#  'arent',
#  'ever',
#  'full',
#  'control',
#  'control',
#  'choose',
#  'right',
#  'moment',
#  'attention',
#  'shifts',
#  'outcomes',
#  'process',
#  'perfectionism',
#  'focuses',
#  'fixed',
#  'outcomes',
#  'excellence',
#  'focuses',
#  'better',
#  'outcomes',
#  'real',
#  'situation',
#  'always',
#  'improved',
#  'since',
#  'perfect',
#  'outcome',
#  'perfection',
#  'impossible',
#  'lets',
#  'see',
#  'tendency',
#  'clearly',
#  'revisit',
#  'perfectionist',
#  'earlier',
#  'former',
#  'perfectionist',
#  'prides',
#  'working',
#  'hard',
#  'paying',
#  'attention',
#  'present',
#  'feels',
#  'great',
#  'satisfaction',
#  'starts',
#  'new',
#  'projects',
#  'steady',
#  'confidence',
#  'endures',
#  'regardless',
#  'difficulties',
#  'underfoot',
#  'work',
#  'uncertain',
#  'persists',
#  'uncertainty',
#  'unknown',
#  'longer',
#  'threat',
#  'matter',
#  'focuses',
#  'taking',
#  'next',
#  'step',
#  'since',
#  'embraces',
#  'imperfection',
#  'gives',
#  'sincere',
#  'effort',
#  'regardless',
#  'motivated',
#  'feels',
#  'lifes',
#  'little',
#  'difficulties',
#  'enough',
#  'deter',
#  'project',
#  'hard',
#  'enough',
#  'setbacks',
#  'failures',
#  'inevitable',
#  'learns',
#  'much',
#  'treats',
#  'like',
#  'precious',
#  'friends',
#  'arent',
#  'exactly',
#  'pleasant',
#  'show',
#  'improve',
#  'grow',
#  'hasnt',
#  'failed',
#  'recently',
#  'knows',
#  'shes',
#  'playing',
#  'safe',
#  'feels',
#  'stuck',
#  'problem',
#  'asking',
#  'help',
#  'advice',
#  'may',
#  'feel',
#  'usual',
#  'anxieties',
#  'stresses',
#  'big',
#  'project',
#  'worries',
#  'longer',
#  'selfinflicted',
#  'general',
#  'serene',
#  'steady',
#  'feels',
#  'work',
#  'good',
#  'enough',
#  'completes',
#  'moves',
#  'others',
#  'achieve',
#  'better',
#  'outcomes',
#  'responds',
#  'openness',
#  'curiosity',
#  'something',
#  'learn',
#  'gladly',
#  'absorbs',
#  'lesson',
#  'illwill',
#  'focuses',
#  'control',
#  'pursuit',
#  'outcome',
#  'opts',
#  'comparison',
#  'game',
#  'always',
#  'rooted',
#  'reality',
#  'moment',
#  'process',
#  'outcomes',
#  'systems',
#  'goals',
#  'growth',
#  'mindset',
#  'fixed',
#  'mindset',
#  'satisficing',
#  'maximizing',
#  'professionalism',
#  'amateurism',
#  'boring',
#  'fundamentals',
#  'flashy',
#  'tricks',
#  'response',
#  'reaction',
#  'agency',
#  'passivity',
#  'presence',
#  'regret',
#  'worry',
#  'matter',
#  'call',
#  'distinction',
#  'dont',
#  'claim',
#  'getting',
#  'easy',
#  'hardly',
#  'expert',
#  'possible',
#  'put',
#  'work',
#  'enough',
#  'time',
#  'practice',
#  'becomes',
#  'automatic',
#  'v',
#  'way',
#  'cruel',
#  'paradox',
#  'preconditions',
#  'meaningful',
#  'change',
#  'wanting',
#  'change',
#  'believing',
#  'change',
#  'possible',
#  'committing',
#  'regular',
#  'practice',
#  'run',
#  'tendency',
#  'enough',
#  'selfinsight',
#  'enough',
#  'selfinflicted',
#  'suffering',
#  'perfectionist',
#  'arrive',
#  'broadly',
#  'speaking',
#  'way',
#  'three',
#  'parts',
#  'first',
#  'train',
#  'mind',
#  'see',
#  'endure',
#  'imperfect',
#  'reality',
#  'psychological',
#  'literature',
#  'recommends',
#  'various',
#  'treatment',
#  'options',
#  'depending',
#  'situation',
#  'three',
#  'cognitivebehavioral',
#  'therapy',
#  'trains',
#  'mind',
#  'challenge',
#  'distorted',
#  'thoughts',
#  'related',
#  'perfectionism',
#  'eg',
#  'im',
#  'failure',
#  'might',
#  'fail',
#  'im',
#  'successful',
#  'ways',
#  'exposure',
#  'response',
#  'prevention',
#  'trains',
#  'mind',
#  'tolerate',
#  'reduce',
#  'mental',
#  'distress',
#  'repeatedly',
#  'facing',
#  'distressing',
#  'thought',
#  'eg',
#  'im',
#  'going',
#  'fail',
#  'yes',
#  'maybe',
#  'mindfulness',
#  'meditation',
#  'trains',
#  ...]

# %% [markdown]
# ## POS-tagging

# %%
pos_tags = pos_tag(filtered_words)
pos_tags
# Out:
# [('unlearning', 'JJ'),
#  ('perfectionism', 'NN'),
#  ('common', 'JJ'),
#  ('idea', 'NN'),
#  ('perfectionism', 'NN'),
#  ('need', 'VBP'),
#  ('perfect', 'JJ'),
#  ('results', 'NNS'),
#  ('maximum', 'JJ'),
#  ('test', 'NN'),
#  ('score', 'NN'),
#  ('flawless', 'NN'),
#  ('recital', 'VBP'),
#  ('unanimous', 'JJ'),
#  ('verdict', 'NN'),
#  ('idea', 'NN'),
#  ('misses', 'VBZ'),
#  ('deeper', 'JJR'),
#  ('reality', 'NN'),
#  ('generally', 'RB'),
#  ('perfectionism', 'NN'),
#  ('tendency', 'NN'),
#  ('stake', 'NN'),
#  ('identity', 'NN'),
#  ('achieving', 'VBG'),
#  ('fixed', 'VBN'),
#  ('outcomes', 'NNS'),
#  ('fixed', 'VBN'),
#  ('outcomes', 'RB'),
#  ('vary', 'JJ'),
#  ('person', 'NN'),
#  ('perfect', 'JJ'),
#  ('performance', 'NN'),
#  ('stereotype', 'NN'),
#  ('fixed', 'VBN'),
#  ('outcome', 'NN'),
#  ('might', 'MD'),
#  ('feeling', 'VB'),
#  ('smart', 'JJ'),
#  ('beautiful', 'NN'),
#  ('right', 'RB'),
#  ('getting', 'VBG'),
#  ('car', 'NN'),
#  ('job', 'NN'),
#  ('weve', 'VBP'),
#  ('craving', 'VBG'),
#  ('long', 'RB'),
#  ('every', 'DT'),
#  ('perfectionist', 'NN'),
#  ('personal', 'JJ'),
#  ('ideal', 'NN'),
#  ('none', 'NN'),
#  ('outcomes', 'VBZ'),
#  ('problems', 'NNS'),
#  ('become', 'VBP'),
#  ('intertwine', 'JJ'),
#  ('identity', 'NN'),
#  ('selfworth', 'NN'),
#  ('perfectionist', 'NN'),
#  ('fame', 'NN'),
#  ('ever', 'RB'),
#  ('feels', 'VBZ'),
#  ('unknown', 'JJ'),
#  ('feels', 'NNS'),
#  ('worthless', 'NN'),
#  ('ashamed', 'VBD'),
#  ('hence', 'JJ'),
#  ('perfectionist', 'NN'),
#  ('stakes', 'NNS'),
#  ('identity', 'NN'),
#  ('achieving', 'VBG'),
#  ('outcomes', 'NNS'),
#  ('meaning', 'VBG'),
#  ('selfworth', 'JJ'),
#  ('depends', 'NNS'),
#  ('realizing', 'VBG'),
#  ('pitiful', 'JJ'),
#  ('wager', 'NN'),
#  ('poor', 'JJ'),
#  ('strategy', 'NN'),
#  ('perfectionism', 'NN'),
#  ('tendency', 'NN'),
#  ('law', 'NN'),
#  ('practice', 'NN'),
#  ('unlearn', 'JJ'),
#  ('replace', 'VB'),
#  ('far', 'RB'),
#  ('better', 'JJR'),
#  ('approaches', 'NNS'),
#  ('clearly', 'RB'),
#  ('see', 'VBP'),
#  ('tendency', 'JJ'),
#  ('choice', 'NN'),
#  ('reinforce', 'NN'),
#  ('actions', 'NNS'),
#  ('unlearn', 'VBP'),
#  ('practice', 'NN'),
#  ('something', 'NN'),
#  ('better', 'RBR'),
#  ('either', 'DT'),
#  ('way', 'NN'),
#  ('decision', 'NN'),
#  ('ii', 'NN'),
#  ('tendency', 'NN'),
#  ('lets', 'NNS'),
#  ('first', 'JJ'),
#  ('see', 'VB'),
#  ('tendency', 'NN'),
#  ('clearly', 'RB'),
#  ('lets', 'VBZ'),
#  ('enter', 'JJ'),
#  ('mind', 'NN'),
#  ('severe', 'JJ'),
#  ('perfectionist', 'JJ'),
#  ('perfectionist', 'NN'),
#  ('always', 'RB'),
#  ('done', 'VBN'),
#  ('well', 'RB'),
#  ('school', 'NN'),
#  ('told', 'VBD'),
#  ('shes', 'NNS'),
#  ('smart', 'JJ'),
#  ('important', 'JJ'),
#  ('people', 'NNS'),
#  ('life', 'NN'),
#  ('part', 'NN'),
#  ('sees', 'VBZ'),
#  ('success', 'NN'),
#  ('affirms', 'NNS'),
#  ('person', 'NN'),
#  ('starts', 'VBZ'),
#  ('new', 'JJ'),
#  ('projects', 'NNS'),
#  ('optimistic', 'JJ'),
#  ('brittle', 'JJ'),
#  ('confidence', 'NN'),
#  ('easy', 'JJ'),
#  ('tasks', 'NNS'),
#  ('small', 'JJ'),
#  ('problems', 'NNS'),
#  ('within', 'IN'),
#  ('grasp', 'JJ'),
#  ('handles', 'NNS'),
#  ('flawlessly', 'RB'),
#  ('difficulties', 'NNS'),
#  ('rise', 'VBP'),
#  ('confidence', 'NN'),
#  ('falters', 'NNS'),
#  ('tendency', 'VBP'),
#  ('milder', 'NN'),
#  ('could', 'MD'),
#  ('push', 'VB'),
#  ('wants', 'VBZ'),
#  ('preserve', 'JJ'),
#  ('selfimage', 'NN'),
#  ('badly', 'RB'),
#  ('refuses', 'VBZ'),
#  ('face', 'NN'),
#  ('imperfect', 'JJ'),
#  ('reality', 'NN'),
#  ('feels', 'NNS'),
#  ('threatened', 'VBN'),
#  ('moderate', 'JJ'),
#  ('setbacks', 'NNS'),
#  ('finds', 'VBZ'),
#  ('number', 'NN'),
#  ('excuses', 'NNS'),
#  ('procrastinate', 'VBP'),
#  ('shes', 'NNS'),
#  ('mood', 'RB'),
#  ('right', 'JJ'),
#  ('place', 'NN'),
#  ('busy', 'JJ'),
#  ('inspired', 'VBN'),
#  ('hungry', 'JJ'),
#  ('full', 'JJ'),
#  ('alert', 'NN'),
#  ('tired', 'VBD'),
#  ('work', 'NN'),
#  ('uncertain', 'JJ'),
#  ('withers', 'NNS'),
#  ('uncertainty', 'NN'),
#  ('means', 'VBZ'),
#  ('unknown', 'JJ'),
#  ('means', 'NNS'),
#  ('risk', 'NN'),
#  ('means', 'VBZ'),
#  ('failure', 'NN'),
#  ('means', 'VBZ'),
#  ('shes', 'NNS'),
#  ('worthless', 'JJ'),
#  ('thought', 'VBD'),
#  ('fumbling', 'VBG'),
#  ('void', 'JJ'),
#  ('terrifies', 'NNS'),
#  ('retreats', 'VBZ'),
#  ('safe', 'JJ'),
#  ('familiar', 'JJ'),
#  ('checks', 'NNS'),
#  ('email', 'VBP'),
#  ('hundredth', 'JJ'),
#  ('time', 'NN'),
#  ('might', 'MD'),
#  ('refuse', 'VB'),
#  ('help', 'NN'),
#  ('kind', 'NN'),
#  ('might', 'MD'),
#  ('procrastinate', 'VB'),
#  ('resort', 'NN'),
#  ('lastminute', 'NN'),
#  ('heroics', 'NNS'),
#  ('might', 'MD'),
#  ('chase', 'VB'),
#  ('standards', 'NNS'),
#  ('delusionally', 'RB'),
#  ('high', 'JJ'),
#  ('way', 'NN'),
#  ('selfsabotage', 'NN'),
#  ('tilts', 'NNS'),
#  ('game', 'NN'),
#  ('favor', 'NN'),
#  ('succeeds', 'VBZ'),
#  ('despite', 'IN'),
#  ('affirms', 'NNS'),
#  ('brilliance', 'NN'),
#  ('talent', 'NN'),
#  ('fails', 'VBZ'),
#  ('survives', 'NNS'),
#  ('unscathed', 'JJ'),
#  ('nobody', 'NN'),
#  ('else', 'RB'),
#  ('playing', 'VBG'),
#  ('impossible', 'JJ'),
#  ('game', 'NN'),
#  ('means', 'VBZ'),
#  ('nobody', 'JJ'),
#  ('make', 'VB'),
#  ('feel', 'NN'),
#  ('inferior', 'JJ'),
#  ('worst', 'JJS'),
#  ('case', 'NN'),
#  ('intentionally', 'RB'),
#  ('fails', 'VBZ'),
#  ('better', 'RBR'),
#  ('thinks', 'NNS'),
#  ('crash', 'VBP'),
#  ('burn', 'VBP'),
#  ('mistaken', 'VBN'),
#  ('someone', 'NN'),
#  ('mediocre', 'NN'),
#  ('tirelessly', 'RB'),
#  ('finds', 'VBZ'),
#  ('excuses', 'NNS'),
#  ('ward', 'IN'),
#  ('rising', 'VBG'),
#  ('anxiety', 'NN'),
#  ('project', 'NN'),
#  ('would', 'MD'),
#  ('difficult', 'JJ'),
#  ('anyone', 'NN'),
#  ('genius', 'NN'),
#  ('could', 'MD'),
#  ('figure', 'VB'),
#  ('never', 'RB'),
#  ('really', 'RB'),
#  ('cared', 'JJ'),
#  ('anyway', 'RB'),
#  ('work', 'NN'),
#  ('simply', 'RB'),
#  ('beneath', 'JJ'),
#  ('lowest', 'JJS'),
#  ('blames', 'VBZ'),
#  ('others', 'NNS'),
#  ('everything', 'NN'),
#  ('would', 'MD'),
#  ('fine', 'VB'),
#  ('werent', 'NN'),
#  ('others', 'NNS'),
#  ('surpass', 'VBP'),
#  ('dynamics', 'NNS'),
#  ('different', 'JJ'),
#  ('money', 'NN'),
#  ('better', 'RBR'),
#  ('connections', 'NNS'),
#  ('savvier', 'JJR'),
#  ('teachers', 'NNS'),
#  ('richer', 'JJR'),
#  ('opportunities', 'NNS'),
#  ('game', 'NN'),
#  ('rigged', 'VBD'),
#  ('start', 'RB'),
#  ('primitive', 'JJ'),
#  ('seethes', 'NNS'),
#  ('may', 'MD'),
#  ('intelligent', 'VB'),
#  ('least', 'JJS'),
#  ('shes', 'NNS'),
#  ('deeper', 'JJR'),
#  ('thinker', 'NN'),
#  ('ethical', 'JJ'),
#  ('human', 'JJ'),
#  ('selfawareness', 'NN'),
#  ('balm', 'NN'),
#  ('becomes', 'VBZ'),
#  ('part', 'NN'),
#  ('defense', 'NN'),
#  ('knows', 'VBZ'),
#  ('sure', 'JJ'),
#  ('personality', 'NN'),
#  ('fault', 'NN'),
#  ('upbringing', 'JJ'),
#  ('shes', 'NNS'),
#  ('idealist', 'VBP'),
#  ('shes', 'NNS'),
#  ('sagely', 'RB'),
#  ('accepting', 'VBG'),
#  ('tendency', 'NN'),
#  ('justify', 'NN'),
#  ('changing', 'VBG'),
#  ('therefore', 'NN'),
#  ('chooses', 'NNS'),
#  ('reinforces', 'VBZ'),
#  ('becomes', 'NNS'),
#  ('cause', 'VBP'),
#  ('effect', 'NN'),
#  ('wont', 'NN'),
#  ('cant', 'JJ'),
#  ('take', 'VB'),
#  ('action', 'NN'),
#  ('try', 'VB'),
#  ('whole', 'JJ'),
#  ('since', 'IN'),
#  ('nothing', 'NN'),
#  ('would', 'MD'),
#  ('excruciating', 'VBG'),
#  ('fail', 'VB'),
#  ('anyway', 'RB'),
#  ('must', 'MD'),
#  ('try', 'VB'),
#  ('effort', 'NN'),
#  ('woven', 'WRB'),
#  ('frustration', 'NN'),
#  ('shame', 'NN'),
#  ('shorn', 'JJ'),
#  ('defenses', 'VBZ'),
#  ('suffers', 'NNS'),
#  ('existentially', 'RB'),
#  ('wagered', 'VBD'),
#  ('selfworth', 'NN'),
#  ('lost', 'VBN'),
#  ('berates', 'NNS'),
#  ('stupid', 'JJ'),
#  ('cant', 'JJ'),
#  ('better', 'JJR'),
#  ('copes', 'NNS'),
#  ('bitter', 'RBR'),
#  ('result', 'NN'),
#  ('failure', 'NN'),
#  ('handle', 'NN'),
#  ('feels', 'VBZ'),
#  ('irrevocably', 'RB'),
#  ('worthless', 'JJ'),
#  ('enters', 'NNS'),
#  ('deeper', 'VBP'),
#  ('hells', 'NNS'),
#  ('name', 'NN'),
#  ('excuses', 'VBZ'),
#  ('valid', 'JJ'),
#  ('right', 'RB'),
#  ('context', 'NN'),
#  ('thats', 'NNS'),
#  ('makes', 'VBZ'),
#  ('good', 'JJ'),
#  ('cover', 'NN'),
#  ('tell', 'NN'),
#  ('comes', 'VBZ'),
#  ('next', 'JJ'),
#  ('personality', 'NN'),
#  ('therefore', 'RB'),
#  ('response', 'NN'),
#  ('therefore', 'NN'),
#  ('doesnt', 'NN'),
#  ('need', 'VBP'),
#  ('change', 'NN'),
#  ('perfectionist', 'NN'),
#  ('fears', 'NNS'),
#  ('setbacks', 'VBZ'),
#  ('uncertainty', 'NN'),
#  ('true', 'JJ'),
#  ('knowledge', 'NN'),
#  ('strengths', 'NNS'),
#  ('weaknesses', 'VBZ'),
#  ('failure', 'NN'),
#  ('cant', 'NN'),
#  ('blamed', 'VBD'),
#  ('others', 'NNS'),
#  ('anything', 'NN'),
#  ('else', 'RB'),
#  ('threatens', 'VBZ'),
#  ('outcomes', 'NNS'),
#  ('fixed', 'VBN'),
#  ('sense', 'NN'),
#  ('self', 'NN'),
#  ('deprives', 'VBZ'),
#  ('explosive', 'JJ'),
#  ('growth', 'NN'),
#  ('comes', 'VBZ'),
#  ('uncertainty', 'NN'),
#  ('struggle', 'NN'),
#  ('open', 'JJ'),
#  ('exploration', 'NN'),
#  ('like', 'IN'),
#  ('tree', 'NN'),
#  ('grows', 'NNS'),
#  ('large', 'JJ'),
#  ('pot', 'NN'),
#  ('hews', 'NNS'),
#  ('familiar', 'JJ'),
#  ('stunts', 'NNS'),
#  ('potential', 'JJ'),
#  ('theory', 'NN'),
#  ('practice', 'NN'),
#  ('dreaming', 'VBG'),
#  ('acting', 'VBG'),
#  ('resentment', 'NN'),
#  ('curiosity', 'NN'),
#  ('fantasy', 'NN'),
#  ('reality', 'NN'),
#  ('dwells', 'VBZ'),
#  ('puddles', 'NNS'),
#  ('fear', 'VBP'),
#  ('ocean', 'JJ'),
#  ('iii', 'JJ'),
#  ('pro', 'JJ'),
#  ('contra', 'FW'),
#  ('perfectionism', 'NN'),
#  ('endures', 'VBZ'),
#  ('merits', 'NNS'),
#  ('must', 'MD'),
#  ('see', 'VB'),
#  ('clearly', 'RB'),
#  ('well', 'RB'),
#  ('establishes', 'RB'),
#  ('high', 'JJ'),
#  ('standard', 'NN'),
#  ('feeds', 'NNS'),
#  ('source', 'NN'),
#  ('intense', 'JJ'),
#  ('energy', 'NN'),
#  ('ie', 'NNS'),
#  ('fear', 'VBP'),
#  ('losing', 'VBG'),
#  ('identity', 'NN'),
#  ('selfworth', 'NN'),
#  ('surprise', 'NN'),
#  ('worlds', 'NN'),
#  ('luminaries', 'NNS'),
#  ('made', 'VBN'),
#  ('contracts', 'NNS'),
#  ('cost', 'VBN'),
#  ('contract', 'NN'),
#  ('present', 'JJ'),
#  ('carl', 'NN'),
#  ('gauss', 'NN'),
#  ('set', 'VBN'),
#  ('mathematics', 'NNS'),
#  ('back', 'RB'),
#  ('decades', 'NNS'),
#  ('contemporaries', 'NNS'),
#  ('begged', 'VBD'),
#  ('relax', 'JJ'),
#  ('frigid', 'JJ'),
#  ('perfection', 'NN'),
#  ('mathematics', 'NNS'),
#  ('might', 'MD'),
#  ('advance', 'VB'),
#  ('rapidly', 'RB'),
#  ('gauss', 'JJ'),
#  ('never', 'RB'),
#  ('relaxed', 'VBP'),
#  ('divulged', 'VBD'),
#  ('knew', 'NNP'),
#  ('quite', 'RB'),
#  ('possible', 'JJ'),
#  ('mathematics', 'NNS'),
#  ('would', 'MD'),
#  ('half', 'VB'),
#  ('century', 'NN'),
#  ('ahead', 'RB'),
#  ('et', 'RB'),
#  ('bell', 'VB'),
#  ('men', 'NNS'),
#  ('mathematics', 'NNS'),
#  ('virgil', 'VBP'),
#  ('almost', 'RB'),
#  ('deprived', 'VBN'),
#  ('world', 'NN'),
#  ('masterpiece', 'NN'),
#  ('last', 'JJ'),
#  ('illness', 'NN'),
#  ('called', 'VBD'),
#  ('cases', 'NNS'),
#  ('containing', 'VBG'),
#  ('manuscripts', 'NNS'),
#  ('intention', 'NN'),
#  ('burning', 'VBG'),
#  ('aeneid', 'JJ'),
#  ('speaks', 'NNS'),
#  ('felt', 'VBD'),
#  ('undertaking', 'JJ'),
#  ('work', 'NN'),
#  ('mistake', 'NN'),
#  ('dissatisfaction', 'NN'),
#  ('work', 'NN'),
#  ('may', 'MD'),
#  ('ascribed', 'VB'),
#  ('passion', 'NN'),
#  ('perfection', 'NN'),
#  ('workmanship', 'WRB'),
#  ('death', 'NN'),
#  ('prevented', 'VBD'),
#  ('attaining', 'VBG'),
#  ('encyclopedia', 'NN'),
#  ('brittanica', 'NN'),
#  ('bill', 'NN'),
#  ('walsh', 'VBP'),
#  ('whose', 'WP$'),
#  ('coaching', 'VBG'),
#  ('career', 'NN'),
#  ('utterly', 'JJ'),
#  ('destroyed', 'VBN'),
#  ('would', 'MD'),
#  ('sit', 'VB'),
#  ('dazed', 'JJ'),
#  ('hot', 'JJ'),
#  ('tub', 'NN'),
#  ('even', 'RB'),
#  ('wins', 'VBZ'),
#  ('despondent', 'NN'),
#  ('miscalculated', 'VBN'),
#  ('play', 'NN'),
#  ('two', 'CD'),
#  ('tortured', 'VBD'),
#  ('person', 'NN'),
#  ('walsh', 'NN'),
#  ('later', 'RB'),
#  ('told', 'VBD'),
#  ('biographer', 'CC'),
#  ('harris', 'JJ'),
#  ('felt', 'JJ'),
#  ('failure', 'NN'),
#  ('personally', 'RB'),
#  ('eventually', 'RB'),
#  ('couldnt', 'JJ'),
#  ('get', 'VB'),
#  ('cant', 'JJ'),
#  ('live', 'JJ'),
#  ('way', 'NN'),
#  ('long', 'JJ'),
#  ('attack', 'JJ'),
#  ('part', 'NN'),
#  ('nervous', 'JJ'),
#  ('system', 'NN'),
#  ('many', 'JJ'),
#  ('times', 'NNS'),
#  ('seth', 'VBP'),
#  ('wickersham', 'JJ'),
#  ('book', 'NN'),
#  ('coach', 'NN'),
#  ('im', 'NN'),
#  ('anywhere', 'RB'),
#  ('near', 'IN'),
#  ('level', 'NN'),
#  ('people', 'NNS'),
#  ('right', 'RB'),
#  ('tell', 'VBP'),
#  ('live', 'JJ'),
#  ('differently', 'RB'),
#  ('shudder', 'VBP'),
#  ('think', 'VB'),
#  ('much', 'JJ'),
#  ('farther', 'NN'),
#  ('could', 'MD'),
#  ('gone', 'VBN'),
#  ('practiced', 'JJ'),
#  ('better', 'JJR'),
#  ('approach', 'NN'),
#  ('prosaically', 'RB'),
#  ('tendency', 'JJ'),
#  ('correlates', 'NNS'),
#  ('stunning', 'VBG'),
#  ('number', 'NN'),
#  ('maladaptive', 'JJ'),
#  ('patterns', 'NNS'),
#  ('often', 'RB'),
#  ('cause', 'VBP'),
#  ('four', 'CD'),
#  ('procrastination', 'NN'),
#  ('fear', 'NN'),
#  ('failure', 'NN'),
#  ('delaying', 'VBG'),
#  ('complex', 'JJ'),
#  ('uncertain', 'JJ'),
#  ('tasks', 'NNS'),
#  ('perfectionist', 'VBP'),
#  ('procrastinates', 'NNS'),
#  ('avoid', 'VBP'),
#  ('confronting', 'VBG'),
#  ('imperfection', 'NN'),
#  ('also', 'RB'),
#  ('slow', 'JJ'),
#  ('ask', 'NN'),
#  ('help', 'NN'),
#  ('would', 'MD'),
#  ('mean', 'VB'),
#  ('admitting', 'VBG'),
#  ('shes', 'NNS'),
#  ('struggling', 'VBG'),
#  ('impostor', 'NN'),
#  ('syndrome', 'JJ'),
#  ('fear', 'NN'),
#  ('found', 'VBD'),
#  ('judged', 'VBN'),
#  ('unworthy', 'JJ'),
#  ('smart', 'JJ'),
#  ('capable', 'JJ'),
#  ('good', 'JJ'),
#  ('enough', 'RB'),
#  ('meet', 'NN'),
#  ('ideal', 'JJ'),
#  ('standard', 'JJ'),
#  ('perfectionist', 'NN'),
#  ('blends', 'NNS'),
#  ('acts', 'VBZ'),
#  ('part', 'NN'),
#  ('fear', 'NN'),
#  ('found', 'VBD'),
#  ('rejected', 'VBD'),
#  ('obsessive', 'JJ'),
#  ('compulsion', 'NN'),
#  ('full', 'JJ'),
#  ('ocd', 'NN'),
#  ('milder', 'NN'),
#  ('forms', 'NNS'),
#  ('example', 'NN'),
#  ('recurring', 'VBG'),
#  ('anxious', 'JJ'),
#  ('fear', 'NN'),
#  ('inadequacy', 'NN'),
#  ('leads', 'VBZ'),
#  ('selfsoothing', 'VBG'),
#  ('response', 'NN'),
#  ('scrolling', 'VBG'),
#  ('twitter', 'JJ'),
#  ('hour', 'NN'),
#  ('burnout', 'IN'),
#  ('see', 'NN'),
#  ('kind', 'NN'),
#  ('ptsd', 'NN'),
#  ('defenseless', 'NN'),
#  ('perfectionist', 'NN'),
#  ('chronically', 'RB'),
#  ('fails', 'VBZ'),
#  ('live', 'JJ'),
#  ('ideal', 'NN'),
#  ('endures', 'NNS'),
#  ('deep', 'JJ'),
#  ('emotional', 'JJ'),
#  ('trauma', 'NN'),
#  ('worst', 'JJS'),
#  ('case', 'NN'),
#  ('loses', 'VBZ'),
#  ('sense', 'NN'),
#  ('selfworth', 'NN'),
#  ('perfectionism', 'NN'),
#  ('might', 'MD'),
#  ('restrict', 'VB'),
#  ('one', 'CD'),
#  ('domain', 'NN'),
#  ('core', 'NN'),
#  ('tendencies', 'NNS'),
#  ('tend', 'VBP'),
#  ('cut', 'VBN'),
#  ('across', 'IN'),
#  ('realms', 'NNS'),
#  ('life', 'NN'),
#  ('quality', 'NN'),
#  ('makes', 'VBZ'),
#  ('valuable', 'JJ'),
#  ('insidious', 'JJ'),
#  ('iv', 'NN'),
#  ('alternative', 'JJ'),
#  ('much', 'JJ'),
#  ('perfectionism', 'NN'),
#  ('learn', 'JJ'),
#  ('children', 'NNS'),
#  ('choose', 'VBP'),
#  ('adults', 'NNS'),
#  ('extent', 'VBP'),
#  ('choose', 'JJ'),
#  ('fools', 'NNS'),
#  ('choice', 'NN'),
#  ('unlearn', 'JJ'),
#  ('perfectionism', 'NN'),
#  ('one', 'CD'),
#  ('alternative', 'NN'),
#  ('similar', 'JJ'),
#  ('flavor', 'NN'),
#  ('excellence', 'NN'),
#  ('differs', 'NNS'),
#  ('two', 'CD'),
#  ('respects', 'NNS'),
#  ('perfectionism', 'NN'),
#  ('focuses', 'VBZ'),
#  ('achieving', 'VBG'),
#  ('excellence', 'NN'),
#  ('focuses', 'NNS'),
#  ('pursuing', 'VBG'),
#  ('success', 'NN'),
#  ('failure', 'NN'),
#  ('arent', 'JJ'),
#  ('ever', 'RB'),
#  ('full', 'JJ'),
#  ('control', 'NN'),
#  ('control', 'NN'),
#  ('choose', 'VBP'),
#  ('right', 'JJ'),
#  ('moment', 'NN'),
#  ('attention', 'NN'),
#  ('shifts', 'NNS'),
#  ('outcomes', 'RB'),
#  ('process', 'JJ'),
#  ('perfectionism', 'NN'),
#  ('focuses', 'VBZ'),
#  ('fixed', 'VBN'),
#  ('outcomes', 'NNS'),
#  ('excellence', 'VBP'),
#  ('focuses', 'NNS'),
#  ('better', 'RBR'),
#  ('outcomes', 'RB'),
#  ('real', 'JJ'),
#  ('situation', 'NN'),
#  ('always', 'RB'),
#  ('improved', 'VBN'),
#  ('since', 'IN'),
#  ('perfect', 'JJ'),
#  ('outcome', 'NN'),
#  ('perfection', 'NN'),
#  ('impossible', 'JJ'),
#  ('lets', 'NNS'),
#  ('see', 'VBP'),
#  ('tendency', 'NN'),
#  ('clearly', 'RB'),
#  ('revisit', 'JJ'),
#  ('perfectionist', 'NN'),
#  ('earlier', 'RBR'),
#  ('former', 'JJ'),
#  ('perfectionist', 'NN'),
#  ('prides', 'NNS'),
#  ('working', 'VBG'),
#  ('hard', 'RB'),
#  ('paying', 'VBG'),
#  ('attention', 'NN'),
#  ('present', 'JJ'),
#  ('feels', 'NNS'),
#  ('great', 'JJ'),
#  ('satisfaction', 'NN'),
#  ('starts', 'VBZ'),
#  ('new', 'JJ'),
#  ('projects', 'NNS'),
#  ('steady', 'JJ'),
#  ('confidence', 'NN'),
#  ('endures', 'NNS'),
#  ('regardless', 'JJ'),
#  ('difficulties', 'NNS'),
#  ('underfoot', 'JJ'),
#  ('work', 'NN'),
#  ('uncertain', 'JJ'),
#  ('persists', 'NNS'),
#  ('uncertainty', 'NN'),
#  ('unknown', 'RB'),
#  ('longer', 'RB'),
#  ('threat', 'NN'),
#  ('matter', 'NN'),
#  ('focuses', 'VBZ'),
#  ('taking', 'VBG'),
#  ('next', 'JJ'),
#  ('step', 'NN'),
#  ('since', 'IN'),
#  ('embraces', 'NNS'),
#  ('imperfection', 'VBP'),
#  ('gives', 'VBZ'),
#  ('sincere', 'JJ'),
#  ('effort', 'NN'),
#  ('regardless', 'RB'),
#  ('motivated', 'VBD'),
#  ('feels', 'NNS'),
#  ('lifes', 'JJ'),
#  ('little', 'JJ'),
#  ('difficulties', 'NNS'),
#  ('enough', 'RB'),
#  ('deter', 'VBP'),
#  ('project', 'JJ'),
#  ('hard', 'JJ'),
#  ('enough', 'RB'),
#  ('setbacks', 'NNS'),
#  ('failures', 'NNS'),
#  ('inevitable', 'JJ'),
#  ('learns', 'NNS'),
#  ('much', 'RB'),
#  ('treats', 'NNS'),
#  ('like', 'IN'),
#  ('precious', 'JJ'),
#  ('friends', 'NNS'),
#  ('arent', 'JJ'),
#  ('exactly', 'RB'),
#  ('pleasant', 'VBP'),
#  ('show', 'NN'),
#  ('improve', 'VB'),
#  ('grow', 'NN'),
#  ('hasnt', 'NN'),
#  ('failed', 'VBD'),
#  ('recently', 'RB'),
#  ('knows', 'VBZ'),
#  ('shes', 'NNS'),
#  ('playing', 'VBG'),
#  ('safe', 'JJ'),
#  ('feels', 'NNS'),
#  ('stuck', 'VBN'),
#  ('problem', 'NN'),
#  ('asking', 'VBG'),
#  ('help', 'NN'),
#  ('advice', 'NN'),
#  ('may', 'MD'),
#  ('feel', 'VB'),
#  ('usual', 'JJ'),
#  ('anxieties', 'NNS'),
#  ('stresses', 'VBZ'),
#  ('big', 'JJ'),
#  ('project', 'NN'),
#  ('worries', 'NNS'),
#  ('longer', 'RBR'),
#  ('selfinflicted', 'VBN'),
#  ('general', 'JJ'),
#  ('serene', 'NN'),
#  ('steady', 'JJ'),
#  ('feels', 'NNS'),
#  ('work', 'VBP'),
#  ('good', 'JJ'),
#  ('enough', 'RB'),
#  ('completes', 'VBZ'),
#  ('moves', 'NNS'),
#  ('others', 'NNS'),
#  ('achieve', 'VBP'),
#  ('better', 'JJR'),
#  ('outcomes', 'NNS'),
#  ('responds', 'VBZ'),
#  ('openness', 'JJ'),
#  ('curiosity', 'NN'),
#  ('something', 'NN'),
#  ('learn', 'VBP'),
#  ('gladly', 'RB'),
#  ('absorbs', 'JJ'),
#  ('lesson', 'NN'),
#  ('illwill', 'NN'),
#  ('focuses', 'VBZ'),
#  ('control', 'VB'),
#  ('pursuit', 'NN'),
#  ('outcome', 'NN'),
#  ('opts', 'NNS'),
#  ('comparison', 'JJ'),
#  ('game', 'NN'),
#  ('always', 'RB'),
#  ('rooted', 'VBN'),
#  ('reality', 'NN'),
#  ('moment', 'NN'),
#  ('process', 'NN'),
#  ('outcomes', 'RB'),
#  ('systems', 'NNS'),
#  ('goals', 'NNS'),
#  ('growth', 'NN'),
#  ('mindset', 'VBP'),
#  ('fixed', 'VBN'),
#  ('mindset', 'NN'),
#  ('satisficing', 'VBG'),
#  ('maximizing', 'VBG'),
#  ('professionalism', 'NN'),
#  ('amateurism', 'NN'),
#  ('boring', 'VBG'),
#  ('fundamentals', 'NNS'),
#  ('flashy', 'JJ'),
#  ('tricks', 'NNS'),
#  ('response', 'NN'),
#  ('reaction', 'NN'),
#  ('agency', 'NN'),
#  ('passivity', 'NN'),
#  ('presence', 'NN'),
#  ('regret', 'NN'),
#  ('worry', 'VBP'),
#  ('matter', 'NN'),
#  ('call', 'NN'),
#  ('distinction', 'NN'),
#  ('dont', 'NN'),
#  ('claim', 'NN'),
#  ('getting', 'VBG'),
#  ('easy', 'JJ'),
#  ('hardly', 'RB'),
#  ('expert', 'VBP'),
#  ('possible', 'JJ'),
#  ('put', 'NN'),
#  ('work', 'NN'),
#  ('enough', 'JJ'),
#  ('time', 'NN'),
#  ('practice', 'NN'),
#  ('becomes', 'VBZ'),
#  ('automatic', 'JJ'),
#  ('v', 'JJ'),
#  ('way', 'NN'),
#  ('cruel', 'NN'),
#  ('paradox', 'NN'),
#  ('preconditions', 'NNS'),
#  ('meaningful', 'JJ'),
#  ('change', 'NN'),
#  ('wanting', 'VBG'),
#  ('change', 'NN'),
#  ('believing', 'VBG'),
#  ('change', 'NN'),
#  ('possible', 'JJ'),
#  ('committing', 'NN'),
#  ('regular', 'JJ'),
#  ('practice', 'NN'),
#  ('run', 'NN'),
#  ('tendency', 'NN'),
#  ('enough', 'JJ'),
#  ('selfinsight', 'NN'),
#  ('enough', 'RB'),
#  ('selfinflicted', 'VBD'),
#  ('suffering', 'VBG'),
#  ('perfectionist', 'NN'),
#  ('arrive', 'JJ'),
#  ('broadly', 'RB'),
#  ('speaking', 'VBG'),
#  ('way', 'NN'),
#  ('three', 'CD'),
#  ('parts', 'NNS'),
#  ('first', 'RB'),
#  ('train', 'VBP'),
#  ('mind', 'NN'),
#  ('see', 'VBP'),
#  ('endure', 'NN'),
#  ('imperfect', 'JJ'),
#  ('reality', 'NN'),
#  ('psychological', 'JJ'),
#  ('literature', 'NN'),
#  ('recommends', 'VBZ'),
#  ('various', 'JJ'),
#  ('treatment', 'NN'),
#  ('options', 'NNS'),
#  ('depending', 'VBG'),
#  ('situation', 'NN'),
#  ('three', 'CD'),
#  ('cognitivebehavioral', 'JJ'),
#  ('therapy', 'NN'),
#  ('trains', 'NNS'),
#  ('mind', 'VBP'),
#  ('challenge', 'NN'),
#  ('distorted', 'VBN'),
#  ('thoughts', 'NNS'),
#  ('related', 'JJ'),
#  ('perfectionism', 'NN'),
#  ('eg', 'NN'),
#  ('im', 'JJ'),
#  ('failure', 'NN'),
#  ('might', 'MD'),
#  ('fail', 'VB'),
#  ('im', 'JJ'),
#  ('successful', 'JJ'),
#  ('ways', 'NNS'),
#  ('exposure', 'VBP'),
#  ('response', 'NN'),
#  ('prevention', 'NN'),
#  ('trains', 'NNS'),
#  ('mind', 'VB'),
#  ('tolerate', 'NN'),
#  ('reduce', 'VB'),
#  ('mental', 'JJ'),
#  ('distress', 'NN'),
#  ('repeatedly', 'RB'),
#  ('facing', 'VBG'),
#  ('distressing', 'VBG'),
#  ('thought', 'VBN'),
#  ('eg', 'JJ'),
#  ('im', 'NN'),
#  ('going', 'VBG'),
#  ('fail', 'JJ'),
#  ('yes', 'NNS'),
#  ('maybe', 'RB'),
#  ('mindfulness', 'JJ'),
#  ('meditation', 'NN'),
#  ('trains', 'NNS'),
#  ...]

# %% [markdown]
# ## Lemmatization

# %%
lemmatizer = WordNetLemmatizer()
lemmas = [lemmatizer.lemmatize(w) for w in filtered_words]
lemmas
# Out:
# ['unlearning',
#  'perfectionism',
#  'common',
#  'idea',
#  'perfectionism',
#  'need',
#  'perfect',
#  'result',
#  'maximum',
#  'test',
#  'score',
#  'flawless',
#  'recital',
#  'unanimous',
#  'verdict',
#  'idea',
#  'miss',
#  'deeper',
#  'reality',
#  'generally',
#  'perfectionism',
#  'tendency',
#  'stake',
#  'identity',
#  'achieving',
#  'fixed',
#  'outcome',
#  'fixed',
#  'outcome',
#  'vary',
#  'person',
#  'perfect',
#  'performance',
#  'stereotype',
#  'fixed',
#  'outcome',
#  'might',
#  'feeling',
#  'smart',
#  'beautiful',
#  'right',
#  'getting',
#  'car',
#  'job',
#  'weve',
#  'craving',
#  'long',
#  'every',
#  'perfectionist',
#  'personal',
#  'ideal',
#  'none',
#  'outcome',
#  'problem',
#  'become',
#  'intertwine',
#  'identity',
#  'selfworth',
#  'perfectionist',
#  'fame',
#  'ever',
#  'feel',
#  'unknown',
#  'feel',
#  'worthless',
#  'ashamed',
#  'hence',
#  'perfectionist',
#  'stake',
#  'identity',
#  'achieving',
#  'outcome',
#  'meaning',
#  'selfworth',
#  'depends',
#  'realizing',
#  'pitiful',
#  'wager',
#  'poor',
#  'strategy',
#  'perfectionism',
#  'tendency',
#  'law',
#  'practice',
#  'unlearn',
#  'replace',
#  'far',
#  'better',
#  'approach',
#  'clearly',
#  'see',
#  'tendency',
#  'choice',
#  'reinforce',
#  'action',
#  'unlearn',
#  'practice',
#  'something',
#  'better',
#  'either',
#  'way',
#  'decision',
#  'ii',
#  'tendency',
#  'let',
#  'first',
#  'see',
#  'tendency',
#  'clearly',
#  'let',
#  'enter',
#  'mind',
#  'severe',
#  'perfectionist',
#  'perfectionist',
#  'always',
#  'done',
#  'well',
#  'school',
#  'told',
#  'shes',
#  'smart',
#  'important',
#  'people',
#  'life',
#  'part',
#  'see',
#  'success',
#  'affirms',
#  'person',
#  'start',
#  'new',
#  'project',
#  'optimistic',
#  'brittle',
#  'confidence',
#  'easy',
#  'task',
#  'small',
#  'problem',
#  'within',
#  'grasp',
#  'handle',
#  'flawlessly',
#  'difficulty',
#  'rise',
#  'confidence',
#  'falter',
#  'tendency',
#  'milder',
#  'could',
#  'push',
#  'want',
#  'preserve',
#  'selfimage',
#  'badly',
#  'refuse',
#  'face',
#  'imperfect',
#  'reality',
#  'feel',
#  'threatened',
#  'moderate',
#  'setback',
#  'find',
#  'number',
#  'excuse',
#  'procrastinate',
#  'shes',
#  'mood',
#  'right',
#  'place',
#  'busy',
#  'inspired',
#  'hungry',
#  'full',
#  'alert',
#  'tired',
#  'work',
#  'uncertain',
#  'withers',
#  'uncertainty',
#  'mean',
#  'unknown',
#  'mean',
#  'risk',
#  'mean',
#  'failure',
#  'mean',
#  'shes',
#  'worthless',
#  'thought',
#  'fumbling',
#  'void',
#  'terrifies',
#  'retreat',
#  'safe',
#  'familiar',
#  'check',
#  'email',
#  'hundredth',
#  'time',
#  'might',
#  'refuse',
#  'help',
#  'kind',
#  'might',
#  'procrastinate',
#  'resort',
#  'lastminute',
#  'heroic',
#  'might',
#  'chase',
#  'standard',
#  'delusionally',
#  'high',
#  'way',
#  'selfsabotage',
#  'tilt',
#  'game',
#  'favor',
#  'succeeds',
#  'despite',
#  'affirms',
#  'brilliance',
#  'talent',
#  'fails',
#  'survives',
#  'unscathed',
#  'nobody',
#  'else',
#  'playing',
#  'impossible',
#  'game',
#  'mean',
#  'nobody',
#  'make',
#  'feel',
#  'inferior',
#  'worst',
#  'case',
#  'intentionally',
#  'fails',
#  'better',
#  'think',
#  'crash',
#  'burn',
#  'mistaken',
#  'someone',
#  'mediocre',
#  'tirelessly',
#  'find',
#  'excuse',
#  'ward',
#  'rising',
#  'anxiety',
#  'project',
#  'would',
#  'difficult',
#  'anyone',
#  'genius',
#  'could',
#  'figure',
#  'never',
#  'really',
#  'cared',
#  'anyway',
#  'work',
#  'simply',
#  'beneath',
#  'lowest',
#  'blame',
#  'others',
#  'everything',
#  'would',
#  'fine',
#  'werent',
#  'others',
#  'surpass',
#  'dynamic',
#  'different',
#  'money',
#  'better',
#  'connection',
#  'savvier',
#  'teacher',
#  'richer',
#  'opportunity',
#  'game',
#  'rigged',
#  'start',
#  'primitive',
#  'seethes',
#  'may',
#  'intelligent',
#  'least',
#  'shes',
#  'deeper',
#  'thinker',
#  'ethical',
#  'human',
#  'selfawareness',
#  'balm',
#  'becomes',
#  'part',
#  'defense',
#  'know',
#  'sure',
#  'personality',
#  'fault',
#  'upbringing',
#  'shes',
#  'idealist',
#  'shes',
#  'sagely',
#  'accepting',
#  'tendency',
#  'justify',
#  'changing',
#  'therefore',
#  'chooses',
#  'reinforces',
#  'becomes',
#  'cause',
#  'effect',
#  'wont',
#  'cant',
#  'take',
#  'action',
#  'try',
#  'whole',
#  'since',
#  'nothing',
#  'would',
#  'excruciating',
#  'fail',
#  'anyway',
#  'must',
#  'try',
#  'effort',
#  'woven',
#  'frustration',
#  'shame',
#  'shorn',
#  'defense',
#  'suffers',
#  'existentially',
#  'wagered',
#  'selfworth',
#  'lost',
#  'berates',
#  'stupid',
#  'cant',
#  'better',
#  'cope',
#  'bitter',
#  'result',
#  'failure',
#  'handle',
#  'feel',
#  'irrevocably',
#  'worthless',
#  'enters',
#  'deeper',
#  'hell',
#  'name',
#  'excuse',
#  'valid',
#  'right',
#  'context',
#  'thats',
#  'make',
#  'good',
#  'cover',
#  'tell',
#  'come',
#  'next',
#  'personality',
#  'therefore',
#  'response',
#  'therefore',
#  'doesnt',
#  'need',
#  'change',
#  'perfectionist',
#  'fear',
#  'setback',
#  'uncertainty',
#  'true',
#  'knowledge',
#  'strength',
#  'weakness',
#  'failure',
#  'cant',
#  'blamed',
#  'others',
#  'anything',
#  'else',
#  'threatens',
#  'outcome',
#  'fixed',
#  'sense',
#  'self',
#  'deprives',
#  'explosive',
#  'growth',
#  'come',
#  'uncertainty',
#  'struggle',
#  'open',
#  'exploration',
#  'like',
#  'tree',
#  'grows',
#  'large',
#  'pot',
#  'hews',
#  'familiar',
#  'stunt',
#  'potential',
#  'theory',
#  'practice',
#  'dreaming',
#  'acting',
#  'resentment',
#  'curiosity',
#  'fantasy',
#  'reality',
#  'dwells',
#  'puddle',
#  'fear',
#  'ocean',
#  'iii',
#  'pro',
#  'contra',
#  'perfectionism',
#  'endures',
#  'merit',
#  'must',
#  'see',
#  'clearly',
#  'well',
#  'establishes',
#  'high',
#  'standard',
#  'feed',
#  'source',
#  'intense',
#  'energy',
#  'ie',
#  'fear',
#  'losing',
#  'identity',
#  'selfworth',
#  'surprise',
#  'world',
#  'luminary',
#  'made',
#  'contract',
#  'cost',
#  'contract',
#  'present',
#  'carl',
#  'gauss',
#  'set',
#  'mathematics',
#  'back',
#  'decade',
#  'contemporary',
#  'begged',
#  'relax',
#  'frigid',
#  'perfection',
#  'mathematics',
#  'might',
#  'advance',
#  'rapidly',
#  'gauss',
#  'never',
#  'relaxed',
#  'divulged',
#  'knew',
#  'quite',
#  'possible',
#  'mathematics',
#  'would',
#  'half',
#  'century',
#  'ahead',
#  'et',
#  'bell',
#  'men',
#  'mathematics',
#  'virgil',
#  'almost',
#  'deprived',
#  'world',
#  'masterpiece',
#  'last',
#  'illness',
#  'called',
#  'case',
#  'containing',
#  'manuscript',
#  'intention',
#  'burning',
#  'aeneid',
#  'speaks',
#  'felt',
#  'undertaking',
#  'work',
#  'mistake',
#  'dissatisfaction',
#  'work',
#  'may',
#  'ascribed',
#  'passion',
#  'perfection',
#  'workmanship',
#  'death',
#  'prevented',
#  'attaining',
#  'encyclopedia',
#  'brittanica',
#  'bill',
#  'walsh',
#  'whose',
#  'coaching',
#  'career',
#  'utterly',
#  'destroyed',
#  'would',
#  'sit',
#  'dazed',
#  'hot',
#  'tub',
#  'even',
#  'win',
#  'despondent',
#  'miscalculated',
#  'play',
#  'two',
#  'tortured',
#  'person',
#  'walsh',
#  'later',
#  'told',
#  'biographer',
#  'harris',
#  'felt',
#  'failure',
#  'personally',
#  'eventually',
#  'couldnt',
#  'get',
#  'cant',
#  'live',
#  'way',
#  'long',
#  'attack',
#  'part',
#  'nervous',
#  'system',
#  'many',
#  'time',
#  'seth',
#  'wickersham',
#  'book',
#  'coach',
#  'im',
#  'anywhere',
#  'near',
#  'level',
#  'people',
#  'right',
#  'tell',
#  'live',
#  'differently',
#  'shudder',
#  'think',
#  'much',
#  'farther',
#  'could',
#  'gone',
#  'practiced',
#  'better',
#  'approach',
#  'prosaically',
#  'tendency',
#  'correlate',
#  'stunning',
#  'number',
#  'maladaptive',
#  'pattern',
#  'often',
#  'cause',
#  'four',
#  'procrastination',
#  'fear',
#  'failure',
#  'delaying',
#  'complex',
#  'uncertain',
#  'task',
#  'perfectionist',
#  'procrastinates',
#  'avoid',
#  'confronting',
#  'imperfection',
#  'also',
#  'slow',
#  'ask',
#  'help',
#  'would',
#  'mean',
#  'admitting',
#  'shes',
#  'struggling',
#  'impostor',
#  'syndrome',
#  'fear',
#  'found',
#  'judged',
#  'unworthy',
#  'smart',
#  'capable',
#  'good',
#  'enough',
#  'meet',
#  'ideal',
#  'standard',
#  'perfectionist',
#  'blend',
#  'act',
#  'part',
#  'fear',
#  'found',
#  'rejected',
#  'obsessive',
#  'compulsion',
#  'full',
#  'ocd',
#  'milder',
#  'form',
#  'example',
#  'recurring',
#  'anxious',
#  'fear',
#  'inadequacy',
#  'lead',
#  'selfsoothing',
#  'response',
#  'scrolling',
#  'twitter',
#  'hour',
#  'burnout',
#  'see',
#  'kind',
#  'ptsd',
#  'defenseless',
#  'perfectionist',
#  'chronically',
#  'fails',
#  'live',
#  'ideal',
#  'endures',
#  'deep',
#  'emotional',
#  'trauma',
#  'worst',
#  'case',
#  'loses',
#  'sense',
#  'selfworth',
#  'perfectionism',
#  'might',
#  'restrict',
#  'one',
#  'domain',
#  'core',
#  'tendency',
#  'tend',
#  'cut',
#  'across',
#  'realm',
#  'life',
#  'quality',
#  'make',
#  'valuable',
#  'insidious',
#  'iv',
#  'alternative',
#  'much',
#  'perfectionism',
#  'learn',
#  'child',
#  'choose',
#  'adult',
#  'extent',
#  'choose',
#  'fool',
#  'choice',
#  'unlearn',
#  'perfectionism',
#  'one',
#  'alternative',
#  'similar',
#  'flavor',
#  'excellence',
#  'differs',
#  'two',
#  'respect',
#  'perfectionism',
#  'focus',
#  'achieving',
#  'excellence',
#  'focus',
#  'pursuing',
#  'success',
#  'failure',
#  'arent',
#  'ever',
#  'full',
#  'control',
#  'control',
#  'choose',
#  'right',
#  'moment',
#  'attention',
#  'shift',
#  'outcome',
#  'process',
#  'perfectionism',
#  'focus',
#  'fixed',
#  'outcome',
#  'excellence',
#  'focus',
#  'better',
#  'outcome',
#  'real',
#  'situation',
#  'always',
#  'improved',
#  'since',
#  'perfect',
#  'outcome',
#  'perfection',
#  'impossible',
#  'let',
#  'see',
#  'tendency',
#  'clearly',
#  'revisit',
#  'perfectionist',
#  'earlier',
#  'former',
#  'perfectionist',
#  'pride',
#  'working',
#  'hard',
#  'paying',
#  'attention',
#  'present',
#  'feel',
#  'great',
#  'satisfaction',
#  'start',
#  'new',
#  'project',
#  'steady',
#  'confidence',
#  'endures',
#  'regardless',
#  'difficulty',
#  'underfoot',
#  'work',
#  'uncertain',
#  'persists',
#  'uncertainty',
#  'unknown',
#  'longer',
#  'threat',
#  'matter',
#  'focus',
#  'taking',
#  'next',
#  'step',
#  'since',
#  'embrace',
#  'imperfection',
#  'give',
#  'sincere',
#  'effort',
#  'regardless',
#  'motivated',
#  'feel',
#  'life',
#  'little',
#  'difficulty',
#  'enough',
#  'deter',
#  'project',
#  'hard',
#  'enough',
#  'setback',
#  'failure',
#  'inevitable',
#  'learns',
#  'much',
#  'treat',
#  'like',
#  'precious',
#  'friend',
#  'arent',
#  'exactly',
#  'pleasant',
#  'show',
#  'improve',
#  'grow',
#  'hasnt',
#  'failed',
#  'recently',
#  'know',
#  'shes',
#  'playing',
#  'safe',
#  'feel',
#  'stuck',
#  'problem',
#  'asking',
#  'help',
#  'advice',
#  'may',
#  'feel',
#  'usual',
#  'anxiety',
#  'stress',
#  'big',
#  'project',
#  'worry',
#  'longer',
#  'selfinflicted',
#  'general',
#  'serene',
#  'steady',
#  'feel',
#  'work',
#  'good',
#  'enough',
#  'completes',
#  'move',
#  'others',
#  'achieve',
#  'better',
#  'outcome',
#  'responds',
#  'openness',
#  'curiosity',
#  'something',
#  'learn',
#  'gladly',
#  'absorbs',
#  'lesson',
#  'illwill',
#  'focus',
#  'control',
#  'pursuit',
#  'outcome',
#  'opts',
#  'comparison',
#  'game',
#  'always',
#  'rooted',
#  'reality',
#  'moment',
#  'process',
#  'outcome',
#  'system',
#  'goal',
#  'growth',
#  'mindset',
#  'fixed',
#  'mindset',
#  'satisficing',
#  'maximizing',
#  'professionalism',
#  'amateurism',
#  'boring',
#  'fundamental',
#  'flashy',
#  'trick',
#  'response',
#  'reaction',
#  'agency',
#  'passivity',
#  'presence',
#  'regret',
#  'worry',
#  'matter',
#  'call',
#  'distinction',
#  'dont',
#  'claim',
#  'getting',
#  'easy',
#  'hardly',
#  'expert',
#  'possible',
#  'put',
#  'work',
#  'enough',
#  'time',
#  'practice',
#  'becomes',
#  'automatic',
#  'v',
#  'way',
#  'cruel',
#  'paradox',
#  'precondition',
#  'meaningful',
#  'change',
#  'wanting',
#  'change',
#  'believing',
#  'change',
#  'possible',
#  'committing',
#  'regular',
#  'practice',
#  'run',
#  'tendency',
#  'enough',
#  'selfinsight',
#  'enough',
#  'selfinflicted',
#  'suffering',
#  'perfectionist',
#  'arrive',
#  'broadly',
#  'speaking',
#  'way',
#  'three',
#  'part',
#  'first',
#  'train',
#  'mind',
#  'see',
#  'endure',
#  'imperfect',
#  'reality',
#  'psychological',
#  'literature',
#  'recommends',
#  'various',
#  'treatment',
#  'option',
#  'depending',
#  'situation',
#  'three',
#  'cognitivebehavioral',
#  'therapy',
#  'train',
#  'mind',
#  'challenge',
#  'distorted',
#  'thought',
#  'related',
#  'perfectionism',
#  'eg',
#  'im',
#  'failure',
#  'might',
#  'fail',
#  'im',
#  'successful',
#  'way',
#  'exposure',
#  'response',
#  'prevention',
#  'train',
#  'mind',
#  'tolerate',
#  'reduce',
#  'mental',
#  'distress',
#  'repeatedly',
#  'facing',
#  'distressing',
#  'thought',
#  'eg',
#  'im',
#  'going',
#  'fail',
#  'yes',
#  'maybe',
#  'mindfulness',
#  'meditation',
#  'train',
#  ...]

# %% [markdown]
# ## Stemming

# %%
porter = PorterStemmer()
porter_stems = [porter.stem(w) for w in filtered_words]
porter_stems
# Out:
# ['unlearn',
#  'perfection',
#  'common',
#  'idea',
#  'perfection',
#  'need',
#  'perfect',
#  'result',
#  'maximum',
#  'test',
#  'score',
#  'flawless',
#  'recit',
#  'unanim',
#  'verdict',
#  'idea',
#  'miss',
#  'deeper',
#  'realiti',
#  'gener',
#  'perfection',
#  'tendenc',
#  'stake',
#  'ident',
#  'achiev',
#  'fix',
#  'outcom',
#  'fix',
#  'outcom',
#  'vari',
#  'person',
#  'perfect',
#  'perform',
#  'stereotyp',
#  'fix',
#  'outcom',
#  'might',
#  'feel',
#  'smart',
#  'beauti',
#  'right',
#  'get',
#  'car',
#  'job',
#  'weve',
#  'crave',
#  'long',
#  'everi',
#  'perfectionist',
#  'person',
#  'ideal',
#  'none',
#  'outcom',
#  'problem',
#  'becom',
#  'intertwin',
#  'ident',
#  'selfworth',
#  'perfectionist',
#  'fame',
#  'ever',
#  'feel',
#  'unknown',
#  'feel',
#  'worthless',
#  'asham',
#  'henc',
#  'perfectionist',
#  'stake',
#  'ident',
#  'achiev',
#  'outcom',
#  'mean',
#  'selfworth',
#  'depend',
#  'realiz',
#  'piti',
#  'wager',
#  'poor',
#  'strategi',
#  'perfection',
#  'tendenc',
#  'law',
#  'practic',
#  'unlearn',
#  'replac',
#  'far',
#  'better',
#  'approach',
#  'clearli',
#  'see',
#  'tendenc',
#  'choic',
#  'reinforc',
#  'action',
#  'unlearn',
#  'practic',
#  'someth',
#  'better',
#  'either',
#  'way',
#  'decis',
#  'ii',
#  'tendenc',
#  'let',
#  'first',
#  'see',
#  'tendenc',
#  'clearli',
#  'let',
#  'enter',
#  'mind',
#  'sever',
#  'perfectionist',
#  'perfectionist',
#  'alway',
#  'done',
#  'well',
#  'school',
#  'told',
#  'she',
#  'smart',
#  'import',
#  'peopl',
#  'life',
#  'part',
#  'see',
#  'success',
#  'affirm',
#  'person',
#  'start',
#  'new',
#  'project',
#  'optimist',
#  'brittl',
#  'confid',
#  'easi',
#  'task',
#  'small',
#  'problem',
#  'within',
#  'grasp',
#  'handl',
#  'flawlessli',
#  'difficulti',
#  'rise',
#  'confid',
#  'falter',
#  'tendenc',
#  'milder',
#  'could',
#  'push',
#  'want',
#  'preserv',
#  'selfimag',
#  'badli',
#  'refus',
#  'face',
#  'imperfect',
#  'realiti',
#  'feel',
#  'threaten',
#  'moder',
#  'setback',
#  'find',
#  'number',
#  'excus',
#  'procrastin',
#  'she',
#  'mood',
#  'right',
#  'place',
#  'busi',
#  'inspir',
#  'hungri',
#  'full',
#  'alert',
#  'tire',
#  'work',
#  'uncertain',
#  'wither',
#  'uncertainti',
#  'mean',
#  'unknown',
#  'mean',
#  'risk',
#  'mean',
#  'failur',
#  'mean',
#  'she',
#  'worthless',
#  'thought',
#  'fumbl',
#  'void',
#  'terrifi',
#  'retreat',
#  'safe',
#  'familiar',
#  'check',
#  'email',
#  'hundredth',
#  'time',
#  'might',
#  'refus',
#  'help',
#  'kind',
#  'might',
#  'procrastin',
#  'resort',
#  'lastminut',
#  'heroic',
#  'might',
#  'chase',
#  'standard',
#  'delusion',
#  'high',
#  'way',
#  'selfsabotag',
#  'tilt',
#  'game',
#  'favor',
#  'succe',
#  'despit',
#  'affirm',
#  'brillianc',
#  'talent',
#  'fail',
#  'surviv',
#  'unscath',
#  'nobodi',
#  'els',
#  'play',
#  'imposs',
#  'game',
#  'mean',
#  'nobodi',
#  'make',
#  'feel',
#  'inferior',
#  'worst',
#  'case',
#  'intent',
#  'fail',
#  'better',
#  'think',
#  'crash',
#  'burn',
#  'mistaken',
#  'someon',
#  'mediocr',
#  'tirelessli',
#  'find',
#  'excus',
#  'ward',
#  'rise',
#  'anxieti',
#  'project',
#  'would',
#  'difficult',
#  'anyon',
#  'geniu',
#  'could',
#  'figur',
#  'never',
#  'realli',
#  'care',
#  'anyway',
#  'work',
#  'simpli',
#  'beneath',
#  'lowest',
#  'blame',
#  'other',
#  'everyth',
#  'would',
#  'fine',
#  'werent',
#  'other',
#  'surpass',
#  'dynam',
#  'differ',
#  'money',
#  'better',
#  'connect',
#  'savvier',
#  'teacher',
#  'richer',
#  'opportun',
#  'game',
#  'rig',
#  'start',
#  'primit',
#  'seeth',
#  'may',
#  'intellig',
#  'least',
#  'she',
#  'deeper',
#  'thinker',
#  'ethic',
#  'human',
#  'selfawar',
#  'balm',
#  'becom',
#  'part',
#  'defens',
#  'know',
#  'sure',
#  'person',
#  'fault',
#  'upbring',
#  'she',
#  'idealist',
#  'she',
#  'sage',
#  'accept',
#  'tendenc',
#  'justifi',
#  'chang',
#  'therefor',
#  'choos',
#  'reinforc',
#  'becom',
#  'caus',
#  'effect',
#  'wont',
#  'cant',
#  'take',
#  'action',
#  'tri',
#  'whole',
#  'sinc',
#  'noth',
#  'would',
#  'excruci',
#  'fail',
#  'anyway',
#  'must',
#  'tri',
#  'effort',
#  'woven',
#  'frustrat',
#  'shame',
#  'shorn',
#  'defens',
#  'suffer',
#  'existenti',
#  'wager',
#  'selfworth',
#  'lost',
#  'berat',
#  'stupid',
#  'cant',
#  'better',
#  'cope',
#  'bitter',
#  'result',
#  'failur',
#  'handl',
#  'feel',
#  'irrevoc',
#  'worthless',
#  'enter',
#  'deeper',
#  'hell',
#  'name',
#  'excus',
#  'valid',
#  'right',
#  'context',
#  'that',
#  'make',
#  'good',
#  'cover',
#  'tell',
#  'come',
#  'next',
#  'person',
#  'therefor',
#  'respons',
#  'therefor',
#  'doesnt',
#  'need',
#  'chang',
#  'perfectionist',
#  'fear',
#  'setback',
#  'uncertainti',
#  'true',
#  'knowledg',
#  'strength',
#  'weak',
#  'failur',
#  'cant',
#  'blame',
#  'other',
#  'anyth',
#  'els',
#  'threaten',
#  'outcom',
#  'fix',
#  'sens',
#  'self',
#  'depriv',
#  'explos',
#  'growth',
#  'come',
#  'uncertainti',
#  'struggl',
#  'open',
#  'explor',
#  'like',
#  'tree',
#  'grow',
#  'larg',
#  'pot',
#  'hew',
#  'familiar',
#  'stunt',
#  'potenti',
#  'theori',
#  'practic',
#  'dream',
#  'act',
#  'resent',
#  'curios',
#  'fantasi',
#  'realiti',
#  'dwell',
#  'puddl',
#  'fear',
#  'ocean',
#  'iii',
#  'pro',
#  'contra',
#  'perfection',
#  'endur',
#  'merit',
#  'must',
#  'see',
#  'clearli',
#  'well',
#  'establish',
#  'high',
#  'standard',
#  'feed',
#  'sourc',
#  'intens',
#  'energi',
#  'ie',
#  'fear',
#  'lose',
#  'ident',
#  'selfworth',
#  'surpris',
#  'world',
#  'luminari',
#  'made',
#  'contract',
#  'cost',
#  'contract',
#  'present',
#  'carl',
#  'gauss',
#  'set',
#  'mathemat',
#  'back',
#  'decad',
#  'contemporari',
#  'beg',
#  'relax',
#  'frigid',
#  'perfect',
#  'mathemat',
#  'might',
#  'advanc',
#  'rapidli',
#  'gauss',
#  'never',
#  'relax',
#  'divulg',
#  'knew',
#  'quit',
#  'possibl',
#  'mathemat',
#  'would',
#  'half',
#  'centuri',
#  'ahead',
#  'et',
#  'bell',
#  'men',
#  'mathemat',
#  'virgil',
#  'almost',
#  'depriv',
#  'world',
#  'masterpiec',
#  'last',
#  'ill',
#  'call',
#  'case',
#  'contain',
#  'manuscript',
#  'intent',
#  'burn',
#  'aeneid',
#  'speak',
#  'felt',
#  'undertak',
#  'work',
#  'mistak',
#  'dissatisfact',
#  'work',
#  'may',
#  'ascrib',
#  'passion',
#  'perfect',
#  'workmanship',
#  'death',
#  'prevent',
#  'attain',
#  'encyclopedia',
#  'brittanica',
#  'bill',
#  'walsh',
#  'whose',
#  'coach',
#  'career',
#  'utterli',
#  'destroy',
#  'would',
#  'sit',
#  'daze',
#  'hot',
#  'tub',
#  'even',
#  'win',
#  'despond',
#  'miscalcul',
#  'play',
#  'two',
#  'tortur',
#  'person',
#  'walsh',
#  'later',
#  'told',
#  'biograph',
#  'harri',
#  'felt',
#  'failur',
#  'person',
#  'eventu',
#  'couldnt',
#  'get',
#  'cant',
#  'live',
#  'way',
#  'long',
#  'attack',
#  'part',
#  'nervou',
#  'system',
#  'mani',
#  'time',
#  'seth',
#  'wickersham',
#  'book',
#  'coach',
#  'im',
#  'anywher',
#  'near',
#  'level',
#  'peopl',
#  'right',
#  'tell',
#  'live',
#  'differ',
#  'shudder',
#  'think',
#  'much',
#  'farther',
#  'could',
#  'gone',
#  'practic',
#  'better',
#  'approach',
#  'prosaic',
#  'tendenc',
#  'correl',
#  'stun',
#  'number',
#  'maladapt',
#  'pattern',
#  'often',
#  'caus',
#  'four',
#  'procrastin',
#  'fear',
#  'failur',
#  'delay',
#  'complex',
#  'uncertain',
#  'task',
#  'perfectionist',
#  'procrastin',
#  'avoid',
#  'confront',
#  'imperfect',
#  'also',
#  'slow',
#  'ask',
#  'help',
#  'would',
#  'mean',
#  'admit',
#  'she',
#  'struggl',
#  'impostor',
#  'syndrom',
#  'fear',
#  'found',
#  'judg',
#  'unworthi',
#  'smart',
#  'capabl',
#  'good',
#  'enough',
#  'meet',
#  'ideal',
#  'standard',
#  'perfectionist',
#  'blend',
#  'act',
#  'part',
#  'fear',
#  'found',
#  'reject',
#  'obsess',
#  'compuls',
#  'full',
#  'ocd',
#  'milder',
#  'form',
#  'exampl',
#  'recur',
#  'anxiou',
#  'fear',
#  'inadequaci',
#  'lead',
#  'selfsooth',
#  'respons',
#  'scroll',
#  'twitter',
#  'hour',
#  'burnout',
#  'see',
#  'kind',
#  'ptsd',
#  'defenseless',
#  'perfectionist',
#  'chronic',
#  'fail',
#  'live',
#  'ideal',
#  'endur',
#  'deep',
#  'emot',
#  'trauma',
#  'worst',
#  'case',
#  'lose',
#  'sens',
#  'selfworth',
#  'perfection',
#  'might',
#  'restrict',
#  'one',
#  'domain',
#  'core',
#  'tendenc',
#  'tend',
#  'cut',
#  'across',
#  'realm',
#  'life',
#  'qualiti',
#  'make',
#  'valuabl',
#  'insidi',
#  'iv',
#  'altern',
#  'much',
#  'perfection',
#  'learn',
#  'children',
#  'choos',
#  'adult',
#  'extent',
#  'choos',
#  'fool',
#  'choic',
#  'unlearn',
#  'perfection',
#  'one',
#  'altern',
#  'similar',
#  'flavor',
#  'excel',
#  'differ',
#  'two',
#  'respect',
#  'perfection',
#  'focus',
#  'achiev',
#  'excel',
#  'focus',
#  'pursu',
#  'success',
#  'failur',
#  'arent',
#  'ever',
#  'full',
#  'control',
#  'control',
#  'choos',
#  'right',
#  'moment',
#  'attent',
#  'shift',
#  'outcom',
#  'process',
#  'perfection',
#  'focus',
#  'fix',
#  'outcom',
#  'excel',
#  'focus',
#  'better',
#  'outcom',
#  'real',
#  'situat',
#  'alway',
#  'improv',
#  'sinc',
#  'perfect',
#  'outcom',
#  'perfect',
#  'imposs',
#  'let',
#  'see',
#  'tendenc',
#  'clearli',
#  'revisit',
#  'perfectionist',
#  'earlier',
#  'former',
#  'perfectionist',
#  'pride',
#  'work',
#  'hard',
#  'pay',
#  'attent',
#  'present',
#  'feel',
#  'great',
#  'satisfact',
#  'start',
#  'new',
#  'project',
#  'steadi',
#  'confid',
#  'endur',
#  'regardless',
#  'difficulti',
#  'underfoot',
#  'work',
#  'uncertain',
#  'persist',
#  'uncertainti',
#  'unknown',
#  'longer',
#  'threat',
#  'matter',
#  'focus',
#  'take',
#  'next',
#  'step',
#  'sinc',
#  'embrac',
#  'imperfect',
#  'give',
#  'sincer',
#  'effort',
#  'regardless',
#  'motiv',
#  'feel',
#  'life',
#  'littl',
#  'difficulti',
#  'enough',
#  'deter',
#  'project',
#  'hard',
#  'enough',
#  'setback',
#  'failur',
#  'inevit',
#  'learn',
#  'much',
#  'treat',
#  'like',
#  'preciou',
#  'friend',
#  'arent',
#  'exactli',
#  'pleasant',
#  'show',
#  'improv',
#  'grow',
#  'hasnt',
#  'fail',
#  'recent',
#  'know',
#  'she',
#  'play',
#  'safe',
#  'feel',
#  'stuck',
#  'problem',
#  'ask',
#  'help',
#  'advic',
#  'may',
#  'feel',
#  'usual',
#  'anxieti',
#  'stress',
#  'big',
#  'project',
#  'worri',
#  'longer',
#  'selfinflict',
#  'gener',
#  'seren',
#  'steadi',
#  'feel',
#  'work',
#  'good',
#  'enough',
#  'complet',
#  'move',
#  'other',
#  'achiev',
#  'better',
#  'outcom',
#  'respond',
#  'open',
#  'curios',
#  'someth',
#  'learn',
#  'gladli',
#  'absorb',
#  'lesson',
#  'illwil',
#  'focus',
#  'control',
#  'pursuit',
#  'outcom',
#  'opt',
#  'comparison',
#  'game',
#  'alway',
#  'root',
#  'realiti',
#  'moment',
#  'process',
#  'outcom',
#  'system',
#  'goal',
#  'growth',
#  'mindset',
#  'fix',
#  'mindset',
#  'satisf',
#  'maxim',
#  'profession',
#  'amateur',
#  'bore',
#  'fundament',
#  'flashi',
#  'trick',
#  'respons',
#  'reaction',
#  'agenc',
#  'passiv',
#  'presenc',
#  'regret',
#  'worri',
#  'matter',
#  'call',
#  'distinct',
#  'dont',
#  'claim',
#  'get',
#  'easi',
#  'hardli',
#  'expert',
#  'possibl',
#  'put',
#  'work',
#  'enough',
#  'time',
#  'practic',
#  'becom',
#  'automat',
#  'v',
#  'way',
#  'cruel',
#  'paradox',
#  'precondit',
#  'meaning',
#  'chang',
#  'want',
#  'chang',
#  'believ',
#  'chang',
#  'possibl',
#  'commit',
#  'regular',
#  'practic',
#  'run',
#  'tendenc',
#  'enough',
#  'selfinsight',
#  'enough',
#  'selfinflict',
#  'suffer',
#  'perfectionist',
#  'arriv',
#  'broadli',
#  'speak',
#  'way',
#  'three',
#  'part',
#  'first',
#  'train',
#  'mind',
#  'see',
#  'endur',
#  'imperfect',
#  'realiti',
#  'psycholog',
#  'literatur',
#  'recommend',
#  'variou',
#  'treatment',
#  'option',
#  'depend',
#  'situat',
#  'three',
#  'cognitivebehavior',
#  'therapi',
#  'train',
#  'mind',
#  'challeng',
#  'distort',
#  'thought',
#  'relat',
#  'perfection',
#  'eg',
#  'im',
#  'failur',
#  'might',
#  'fail',
#  'im',
#  'success',
#  'way',
#  'exposur',
#  'respons',
#  'prevent',
#  'train',
#  'mind',
#  'toler',
#  'reduc',
#  'mental',
#  'distress',
#  'repeatedli',
#  'face',
#  'distress',
#  'thought',
#  'eg',
#  'im',
#  'go',
#  'fail',
#  'ye',
#  'mayb',
#  'mind',
#  'medit',
#  'train',
#  ...]

# %%
snowball = SnowballStemmer('english')
snowball_stems = [snowball.stem(w) for w in filtered_words]
snowball_stems
# Out:
# ['unlearn',
#  'perfection',
#  'common',
#  'idea',
#  'perfection',
#  'need',
#  'perfect',
#  'result',
#  'maximum',
#  'test',
#  'score',
#  'flawless',
#  'recit',
#  'unanim',
#  'verdict',
#  'idea',
#  'miss',
#  'deeper',
#  'realiti',
#  'general',
#  'perfection',
#  'tendenc',
#  'stake',
#  'ident',
#  'achiev',
#  'fix',
#  'outcom',
#  'fix',
#  'outcom',
#  'vari',
#  'person',
#  'perfect',
#  'perform',
#  'stereotyp',
#  'fix',
#  'outcom',
#  'might',
#  'feel',
#  'smart',
#  'beauti',
#  'right',
#  'get',
#  'car',
#  'job',
#  'weve',
#  'crave',
#  'long',
#  'everi',
#  'perfectionist',
#  'person',
#  'ideal',
#  'none',
#  'outcom',
#  'problem',
#  'becom',
#  'intertwin',
#  'ident',
#  'selfworth',
#  'perfectionist',
#  'fame',
#  'ever',
#  'feel',
#  'unknown',
#  'feel',
#  'worthless',
#  'asham',
#  'henc',
#  'perfectionist',
#  'stake',
#  'ident',
#  'achiev',
#  'outcom',
#  'mean',
#  'selfworth',
#  'depend',
#  'realiz',
#  'piti',
#  'wager',
#  'poor',
#  'strategi',
#  'perfection',
#  'tendenc',
#  'law',
#  'practic',
#  'unlearn',
#  'replac',
#  'far',
#  'better',
#  'approach',
#  'clear',
#  'see',
#  'tendenc',
#  'choic',
#  'reinforc',
#  'action',
#  'unlearn',
#  'practic',
#  'someth',
#  'better',
#  'either',
#  'way',
#  'decis',
#  'ii',
#  'tendenc',
#  'let',
#  'first',
#  'see',
#  'tendenc',
#  'clear',
#  'let',
#  'enter',
#  'mind',
#  'sever',
#  'perfectionist',
#  'perfectionist',
#  'alway',
#  'done',
#  'well',
#  'school',
#  'told',
#  'shes',
#  'smart',
#  'import',
#  'peopl',
#  'life',
#  'part',
#  'see',
#  'success',
#  'affirm',
#  'person',
#  'start',
#  'new',
#  'project',
#  'optimist',
#  'brittl',
#  'confid',
#  'easi',
#  'task',
#  'small',
#  'problem',
#  'within',
#  'grasp',
#  'handl',
#  'flawless',
#  'difficulti',
#  'rise',
#  'confid',
#  'falter',
#  'tendenc',
#  'milder',
#  'could',
#  'push',
#  'want',
#  'preserv',
#  'selfimag',
#  'bad',
#  'refus',
#  'face',
#  'imperfect',
#  'realiti',
#  'feel',
#  'threaten',
#  'moder',
#  'setback',
#  'find',
#  'number',
#  'excus',
#  'procrastin',
#  'shes',
#  'mood',
#  'right',
#  'place',
#  'busi',
#  'inspir',
#  'hungri',
#  'full',
#  'alert',
#  'tire',
#  'work',
#  'uncertain',
#  'wither',
#  'uncertainti',
#  'mean',
#  'unknown',
#  'mean',
#  'risk',
#  'mean',
#  'failur',
#  'mean',
#  'shes',
#  'worthless',
#  'thought',
#  'fumbl',
#  'void',
#  'terrifi',
#  'retreat',
#  'safe',
#  'familiar',
#  'check',
#  'email',
#  'hundredth',
#  'time',
#  'might',
#  'refus',
#  'help',
#  'kind',
#  'might',
#  'procrastin',
#  'resort',
#  'lastminut',
#  'heroic',
#  'might',
#  'chase',
#  'standard',
#  'delusion',
#  'high',
#  'way',
#  'selfsabotag',
#  'tilt',
#  'game',
#  'favor',
#  'succeed',
#  'despit',
#  'affirm',
#  'brillianc',
#  'talent',
#  'fail',
#  'surviv',
#  'unscath',
#  'nobodi',
#  'els',
#  'play',
#  'imposs',
#  'game',
#  'mean',
#  'nobodi',
#  'make',
#  'feel',
#  'inferior',
#  'worst',
#  'case',
#  'intent',
#  'fail',
#  'better',
#  'think',
#  'crash',
#  'burn',
#  'mistaken',
#  'someon',
#  'mediocr',
#  'tireless',
#  'find',
#  'excus',
#  'ward',
#  'rise',
#  'anxieti',
#  'project',
#  'would',
#  'difficult',
#  'anyon',
#  'genius',
#  'could',
#  'figur',
#  'never',
#  'realli',
#  'care',
#  'anyway',
#  'work',
#  'simpli',
#  'beneath',
#  'lowest',
#  'blame',
#  'other',
#  'everyth',
#  'would',
#  'fine',
#  'werent',
#  'other',
#  'surpass',
#  'dynam',
#  'differ',
#  'money',
#  'better',
#  'connect',
#  'savvier',
#  'teacher',
#  'richer',
#  'opportun',
#  'game',
#  'rig',
#  'start',
#  'primit',
#  'seeth',
#  'may',
#  'intellig',
#  'least',
#  'shes',
#  'deeper',
#  'thinker',
#  'ethic',
#  'human',
#  'selfawar',
#  'balm',
#  'becom',
#  'part',
#  'defens',
#  'know',
#  'sure',
#  'person',
#  'fault',
#  'upbring',
#  'shes',
#  'idealist',
#  'shes',
#  'sage',
#  'accept',
#  'tendenc',
#  'justifi',
#  'chang',
#  'therefor',
#  'choos',
#  'reinforc',
#  'becom',
#  'caus',
#  'effect',
#  'wont',
#  'cant',
#  'take',
#  'action',
#  'tri',
#  'whole',
#  'sinc',
#  'noth',
#  'would',
#  'excruci',
#  'fail',
#  'anyway',
#  'must',
#  'tri',
#  'effort',
#  'woven',
#  'frustrat',
#  'shame',
#  'shorn',
#  'defens',
#  'suffer',
#  'existenti',
#  'wager',
#  'selfworth',
#  'lost',
#  'berat',
#  'stupid',
#  'cant',
#  'better',
#  'cope',
#  'bitter',
#  'result',
#  'failur',
#  'handl',
#  'feel',
#  'irrevoc',
#  'worthless',
#  'enter',
#  'deeper',
#  'hell',
#  'name',
#  'excus',
#  'valid',
#  'right',
#  'context',
#  'that',
#  'make',
#  'good',
#  'cover',
#  'tell',
#  'come',
#  'next',
#  'person',
#  'therefor',
#  'respons',
#  'therefor',
#  'doesnt',
#  'need',
#  'chang',
#  'perfectionist',
#  'fear',
#  'setback',
#  'uncertainti',
#  'true',
#  'knowledg',
#  'strength',
#  'weak',
#  'failur',
#  'cant',
#  'blame',
#  'other',
#  'anyth',
#  'els',
#  'threaten',
#  'outcom',
#  'fix',
#  'sens',
#  'self',
#  'depriv',
#  'explos',
#  'growth',
#  'come',
#  'uncertainti',
#  'struggl',
#  'open',
#  'explor',
#  'like',
#  'tree',
#  'grow',
#  'larg',
#  'pot',
#  'hew',
#  'familiar',
#  'stunt',
#  'potenti',
#  'theori',
#  'practic',
#  'dream',
#  'act',
#  'resent',
#  'curios',
#  'fantasi',
#  'realiti',
#  'dwell',
#  'puddl',
#  'fear',
#  'ocean',
#  'iii',
#  'pro',
#  'contra',
#  'perfection',
#  'endur',
#  'merit',
#  'must',
#  'see',
#  'clear',
#  'well',
#  'establish',
#  'high',
#  'standard',
#  'feed',
#  'sourc',
#  'intens',
#  'energi',
#  'ie',
#  'fear',
#  'lose',
#  'ident',
#  'selfworth',
#  'surpris',
#  'world',
#  'luminari',
#  'made',
#  'contract',
#  'cost',
#  'contract',
#  'present',
#  'carl',
#  'gauss',
#  'set',
#  'mathemat',
#  'back',
#  'decad',
#  'contemporari',
#  'beg',
#  'relax',
#  'frigid',
#  'perfect',
#  'mathemat',
#  'might',
#  'advanc',
#  'rapid',
#  'gauss',
#  'never',
#  'relax',
#  'divulg',
#  'knew',
#  'quit',
#  'possibl',
#  'mathemat',
#  'would',
#  'half',
#  'centuri',
#  'ahead',
#  'et',
#  'bell',
#  'men',
#  'mathemat',
#  'virgil',
#  'almost',
#  'depriv',
#  'world',
#  'masterpiec',
#  'last',
#  'ill',
#  'call',
#  'case',
#  'contain',
#  'manuscript',
#  'intent',
#  'burn',
#  'aeneid',
#  'speak',
#  'felt',
#  'undertak',
#  'work',
#  'mistak',
#  'dissatisfact',
#  'work',
#  'may',
#  'ascrib',
#  'passion',
#  'perfect',
#  'workmanship',
#  'death',
#  'prevent',
#  'attain',
#  'encyclopedia',
#  'brittanica',
#  'bill',
#  'walsh',
#  'whose',
#  'coach',
#  'career',
#  'utter',
#  'destroy',
#  'would',
#  'sit',
#  'daze',
#  'hot',
#  'tub',
#  'even',
#  'win',
#  'despond',
#  'miscalcul',
#  'play',
#  'two',
#  'tortur',
#  'person',
#  'walsh',
#  'later',
#  'told',
#  'biograph',
#  'harri',
#  'felt',
#  'failur',
#  'person',
#  'eventu',
#  'couldnt',
#  'get',
#  'cant',
#  'live',
#  'way',
#  'long',
#  'attack',
#  'part',
#  'nervous',
#  'system',
#  'mani',
#  'time',
#  'seth',
#  'wickersham',
#  'book',
#  'coach',
#  'im',
#  'anywher',
#  'near',
#  'level',
#  'peopl',
#  'right',
#  'tell',
#  'live',
#  'differ',
#  'shudder',
#  'think',
#  'much',
#  'farther',
#  'could',
#  'gone',
#  'practic',
#  'better',
#  'approach',
#  'prosaic',
#  'tendenc',
#  'correl',
#  'stun',
#  'number',
#  'maladapt',
#  'pattern',
#  'often',
#  'caus',
#  'four',
#  'procrastin',
#  'fear',
#  'failur',
#  'delay',
#  'complex',
#  'uncertain',
#  'task',
#  'perfectionist',
#  'procrastin',
#  'avoid',
#  'confront',
#  'imperfect',
#  'also',
#  'slow',
#  'ask',
#  'help',
#  'would',
#  'mean',
#  'admit',
#  'shes',
#  'struggl',
#  'impostor',
#  'syndrom',
#  'fear',
#  'found',
#  'judg',
#  'unworthi',
#  'smart',
#  'capabl',
#  'good',
#  'enough',
#  'meet',
#  'ideal',
#  'standard',
#  'perfectionist',
#  'blend',
#  'act',
#  'part',
#  'fear',
#  'found',
#  'reject',
#  'obsess',
#  'compuls',
#  'full',
#  'ocd',
#  'milder',
#  'form',
#  'exampl',
#  'recur',
#  'anxious',
#  'fear',
#  'inadequaci',
#  'lead',
#  'selfsooth',
#  'respons',
#  'scroll',
#  'twitter',
#  'hour',
#  'burnout',
#  'see',
#  'kind',
#  'ptsd',
#  'defenseless',
#  'perfectionist',
#  'chronic',
#  'fail',
#  'live',
#  'ideal',
#  'endur',
#  'deep',
#  'emot',
#  'trauma',
#  'worst',
#  'case',
#  'lose',
#  'sens',
#  'selfworth',
#  'perfection',
#  'might',
#  'restrict',
#  'one',
#  'domain',
#  'core',
#  'tendenc',
#  'tend',
#  'cut',
#  'across',
#  'realm',
#  'life',
#  'qualiti',
#  'make',
#  'valuabl',
#  'insidi',
#  'iv',
#  'altern',
#  'much',
#  'perfection',
#  'learn',
#  'children',
#  'choos',
#  'adult',
#  'extent',
#  'choos',
#  'fool',
#  'choic',
#  'unlearn',
#  'perfection',
#  'one',
#  'altern',
#  'similar',
#  'flavor',
#  'excel',
#  'differ',
#  'two',
#  'respect',
#  'perfection',
#  'focus',
#  'achiev',
#  'excel',
#  'focus',
#  'pursu',
#  'success',
#  'failur',
#  'arent',
#  'ever',
#  'full',
#  'control',
#  'control',
#  'choos',
#  'right',
#  'moment',
#  'attent',
#  'shift',
#  'outcom',
#  'process',
#  'perfection',
#  'focus',
#  'fix',
#  'outcom',
#  'excel',
#  'focus',
#  'better',
#  'outcom',
#  'real',
#  'situat',
#  'alway',
#  'improv',
#  'sinc',
#  'perfect',
#  'outcom',
#  'perfect',
#  'imposs',
#  'let',
#  'see',
#  'tendenc',
#  'clear',
#  'revisit',
#  'perfectionist',
#  'earlier',
#  'former',
#  'perfectionist',
#  'pride',
#  'work',
#  'hard',
#  'pay',
#  'attent',
#  'present',
#  'feel',
#  'great',
#  'satisfact',
#  'start',
#  'new',
#  'project',
#  'steadi',
#  'confid',
#  'endur',
#  'regardless',
#  'difficulti',
#  'underfoot',
#  'work',
#  'uncertain',
#  'persist',
#  'uncertainti',
#  'unknown',
#  'longer',
#  'threat',
#  'matter',
#  'focus',
#  'take',
#  'next',
#  'step',
#  'sinc',
#  'embrac',
#  'imperfect',
#  'give',
#  'sincer',
#  'effort',
#  'regardless',
#  'motiv',
#  'feel',
#  'life',
#  'littl',
#  'difficulti',
#  'enough',
#  'deter',
#  'project',
#  'hard',
#  'enough',
#  'setback',
#  'failur',
#  'inevit',
#  'learn',
#  'much',
#  'treat',
#  'like',
#  'precious',
#  'friend',
#  'arent',
#  'exact',
#  'pleasant',
#  'show',
#  'improv',
#  'grow',
#  'hasnt',
#  'fail',
#  'recent',
#  'know',
#  'shes',
#  'play',
#  'safe',
#  'feel',
#  'stuck',
#  'problem',
#  'ask',
#  'help',
#  'advic',
#  'may',
#  'feel',
#  'usual',
#  'anxieti',
#  'stress',
#  'big',
#  'project',
#  'worri',
#  'longer',
#  'selfinflict',
#  'general',
#  'seren',
#  'steadi',
#  'feel',
#  'work',
#  'good',
#  'enough',
#  'complet',
#  'move',
#  'other',
#  'achiev',
#  'better',
#  'outcom',
#  'respond',
#  'open',
#  'curios',
#  'someth',
#  'learn',
#  'glad',
#  'absorb',
#  'lesson',
#  'illwil',
#  'focus',
#  'control',
#  'pursuit',
#  'outcom',
#  'opt',
#  'comparison',
#  'game',
#  'alway',
#  'root',
#  'realiti',
#  'moment',
#  'process',
#  'outcom',
#  'system',
#  'goal',
#  'growth',
#  'mindset',
#  'fix',
#  'mindset',
#  'satisf',
#  'maxim',
#  'profession',
#  'amateur',
#  'bore',
#  'fundament',
#  'flashi',
#  'trick',
#  'respons',
#  'reaction',
#  'agenc',
#  'passiv',
#  'presenc',
#  'regret',
#  'worri',
#  'matter',
#  'call',
#  'distinct',
#  'dont',
#  'claim',
#  'get',
#  'easi',
#  'hard',
#  'expert',
#  'possibl',
#  'put',
#  'work',
#  'enough',
#  'time',
#  'practic',
#  'becom',
#  'automat',
#  'v',
#  'way',
#  'cruel',
#  'paradox',
#  'precondit',
#  'meaning',
#  'chang',
#  'want',
#  'chang',
#  'believ',
#  'chang',
#  'possibl',
#  'commit',
#  'regular',
#  'practic',
#  'run',
#  'tendenc',
#  'enough',
#  'selfinsight',
#  'enough',
#  'selfinflict',
#  'suffer',
#  'perfectionist',
#  'arriv',
#  'broad',
#  'speak',
#  'way',
#  'three',
#  'part',
#  'first',
#  'train',
#  'mind',
#  'see',
#  'endur',
#  'imperfect',
#  'realiti',
#  'psycholog',
#  'literatur',
#  'recommend',
#  'various',
#  'treatment',
#  'option',
#  'depend',
#  'situat',
#  'three',
#  'cognitivebehavior',
#  'therapi',
#  'train',
#  'mind',
#  'challeng',
#  'distort',
#  'thought',
#  'relat',
#  'perfection',
#  'eg',
#  'im',
#  'failur',
#  'might',
#  'fail',
#  'im',
#  'success',
#  'way',
#  'exposur',
#  'respons',
#  'prevent',
#  'train',
#  'mind',
#  'toler',
#  'reduc',
#  'mental',
#  'distress',
#  'repeat',
#  'face',
#  'distress',
#  'thought',
#  'eg',
#  'im',
#  'go',
#  'fail',
#  'yes',
#  'mayb',
#  'mind',
#  'medit',
#  'train',
#  ...]

# %%
lancaster = LancasterStemmer()
lancaster_stems = [lancaster.stem(w) for w in filtered_words]
lancaster_stems
# Out:
# ['unlearn',
#  'perfect',
#  'common',
#  'ide',
#  'perfect',
#  'nee',
#  'perfect',
#  'result',
#  'maxim',
#  'test',
#  'scor',
#  'flawless',
#  'recit',
#  'unanim',
#  'verdict',
#  'ide',
#  'miss',
#  'deep',
#  'real',
#  'gen',
#  'perfect',
#  'tend',
#  'stak',
#  'id',
#  'achiev',
#  'fix',
#  'outcom',
#  'fix',
#  'outcom',
#  'vary',
#  'person',
#  'perfect',
#  'perform',
#  'stereotyp',
#  'fix',
#  'outcom',
#  'might',
#  'feel',
#  'smart',
#  'beauty',
#  'right',
#  'get',
#  'car',
#  'job',
#  'wev',
#  'crav',
#  'long',
#  'every',
#  'perfect',
#  'person',
#  'id',
#  'non',
#  'outcom',
#  'problem',
#  'becom',
#  'intertwin',
#  'id',
#  'selfwor',
#  'perfect',
#  'fam',
#  'ev',
#  'feel',
#  'unknown',
#  'feel',
#  'worthless',
#  'asham',
#  'hent',
#  'perfect',
#  'stak',
#  'id',
#  'achiev',
#  'outcom',
#  'mean',
#  'selfwor',
#  'depend',
#  'real',
#  'pity',
#  'wag',
#  'poor',
#  'strategy',
#  'perfect',
#  'tend',
#  'law',
#  'pract',
#  'unlearn',
#  'replac',
#  'far',
#  'bet',
#  'approach',
#  'clear',
#  'see',
#  'tend',
#  'cho',
#  'reinforc',
#  'act',
#  'unlearn',
#  'pract',
#  'someth',
#  'bet',
#  'eith',
#  'way',
#  'decid',
#  'ii',
#  'tend',
#  'let',
#  'first',
#  'see',
#  'tend',
#  'clear',
#  'let',
#  'ent',
#  'mind',
#  'sev',
#  'perfect',
#  'perfect',
#  'alway',
#  'don',
#  'wel',
#  'school',
#  'told',
#  'she',
#  'smart',
#  'import',
#  'peopl',
#  'lif',
#  'part',
#  'see',
#  'success',
#  'affirm',
#  'person',
#  'start',
#  'new',
#  'project',
#  'optim',
#  'brittl',
#  'confid',
#  'easy',
#  'task',
#  'smal',
#  'problem',
#  'within',
#  'grasp',
#  'handl',
#  'flawless',
#  'difficul',
#  'ris',
#  'confid',
#  'falt',
#  'tend',
#  'mild',
#  'could',
#  'push',
#  'want',
#  'preserv',
#  'selfim',
#  'bad',
#  'refus',
#  'fac',
#  'imperfect',
#  'real',
#  'feel',
#  'threatened',
#  'mod',
#  'setback',
#  'find',
#  'numb',
#  'excus',
#  'procrastin',
#  'she',
#  'mood',
#  'right',
#  'plac',
#  'busy',
#  'inspir',
#  'hungry',
#  'ful',
#  'alert',
#  'tir',
#  'work',
#  'uncertain',
#  'with',
#  'uncertainty',
#  'mean',
#  'unknown',
#  'mean',
#  'risk',
#  'mean',
#  'fail',
#  'mean',
#  'she',
#  'worthless',
#  'thought',
#  'fumbl',
#  'void',
#  'terr',
#  'ret',
#  'saf',
#  'famili',
#  'check',
#  'email',
#  'hundred',
#  'tim',
#  'might',
#  'refus',
#  'help',
#  'kind',
#  'might',
#  'procrastin',
#  'resort',
#  'lastminut',
#  'hero',
#  'might',
#  'chas',
#  'standard',
#  'delud',
#  'high',
#  'way',
#  'selfsabot',
#  'tilt',
#  'gam',
#  'fav',
#  'success',
#  'despit',
#  'affirm',
#  'bril',
#  'tal',
#  'fail',
#  'surv',
#  'unscath',
#  'nobody',
#  'els',
#  'play',
#  'imposs',
#  'gam',
#  'mean',
#  'nobody',
#  'mak',
#  'feel',
#  'infery',
#  'worst',
#  'cas',
#  'int',
#  'fail',
#  'bet',
#  'think',
#  'crash',
#  'burn',
#  'mistak',
#  'someon',
#  'mediocr',
#  'tireless',
#  'find',
#  'excus',
#  'ward',
#  'ris',
#  'anxy',
#  'project',
#  'would',
#  'difficult',
#  'anyon',
#  'geni',
#  'could',
#  'fig',
#  'nev',
#  'real',
#  'car',
#  'anyway',
#  'work',
#  'simply',
#  'benea',
#  'lowest',
#  'blam',
#  'oth',
#  'everyth',
#  'would',
#  'fin',
#  'wer',
#  'oth',
#  'surpass',
#  'dynam',
#  'diff',
#  'money',
#  'bet',
#  'connect',
#  'savvy',
#  'teach',
#  'rich',
#  'opportun',
#  'gam',
#  'rig',
#  'start',
#  'primit',
#  'seeth',
#  'may',
#  'intellig',
#  'least',
#  'she',
#  'deep',
#  'think',
#  'eth',
#  'hum',
#  'selfaw',
#  'balm',
#  'becom',
#  'part',
#  'defens',
#  'know',
#  'sur',
#  'person',
#  'fault',
#  'upbr',
#  'she',
#  'id',
#  'she',
#  'sag',
#  'acceiv',
#  'tend',
#  'just',
#  'chang',
#  'theref',
#  'choos',
#  'reinforc',
#  'becom',
#  'caus',
#  'effect',
#  'wont',
#  'cant',
#  'tak',
#  'act',
#  'try',
#  'whol',
#  'sint',
#  'noth',
#  'would',
#  'excrucy',
#  'fail',
#  'anyway',
#  'must',
#  'try',
#  'effort',
#  'wov',
#  'frust',
#  'sham',
#  'shorn',
#  'defens',
#  'suff',
#  'ex',
#  'wag',
#  'selfwor',
#  'lost',
#  'ber',
#  'stupid',
#  'cant',
#  'bet',
#  'cop',
#  'bit',
#  'result',
#  'fail',
#  'handl',
#  'feel',
#  'irrevoc',
#  'worthless',
#  'ent',
#  'deep',
#  'hel',
#  'nam',
#  'excus',
#  'valid',
#  'right',
#  'context',
#  'that',
#  'mak',
#  'good',
#  'cov',
#  'tel',
#  'com',
#  'next',
#  'person',
#  'theref',
#  'respons',
#  'theref',
#  'doesnt',
#  'nee',
#  'chang',
#  'perfect',
#  'fear',
#  'setback',
#  'uncertainty',
#  'tru',
#  'knowledg',
#  'strengths',
#  'weak',
#  'fail',
#  'cant',
#  'blam',
#  'oth',
#  'anyth',
#  'els',
#  'threatens',
#  'outcom',
#  'fix',
#  'sens',
#  'self',
#  'depr',
#  'explod',
#  'grow',
#  'com',
#  'uncertainty',
#  'struggle',
#  'op',
#  'expl',
#  'lik',
#  'tre',
#  'grow',
#  'larg',
#  'pot',
#  'hew',
#  'famili',
#  'stunt',
#  'pot',
#  'the',
#  'pract',
#  'dream',
#  'act',
#  'res',
#  'curios',
#  'fantasy',
#  'real',
#  'dwel',
#  'puddl',
#  'fear',
#  'oc',
#  'ii',
#  'pro',
#  'contr',
#  'perfect',
#  'end',
#  'merit',
#  'must',
#  'see',
#  'clear',
#  'wel',
#  'est',
#  'high',
#  'standard',
#  'fee',
#  'sourc',
#  'intens',
#  'energy',
#  'ie',
#  'fear',
#  'los',
#  'id',
#  'selfwor',
#  'surpr',
#  'world',
#  'lumin',
#  'mad',
#  'contract',
#  'cost',
#  'contract',
#  'pres',
#  'carl',
#  'gauss',
#  'set',
#  'mathem',
#  'back',
#  'decad',
#  'contemp',
#  'beg',
#  'relax',
#  'frigid',
#  'perfect',
#  'mathem',
#  'might',
#  'adv',
#  'rapid',
#  'gauss',
#  'nev',
#  'relax',
#  'divulg',
#  'knew',
#  'quit',
#  'poss',
#  'mathem',
#  'would',
#  'half',
#  'century',
#  'ahead',
#  'et',
#  'bel',
#  'men',
#  'mathem',
#  'virgil',
#  'almost',
#  'depr',
#  'world',
#  'masterpiec',
#  'last',
#  'il',
#  'cal',
#  'cas',
#  'contain',
#  'manuscrib',
#  'int',
#  'burn',
#  'aeneid',
#  'speak',
#  'felt',
#  'undertak',
#  'work',
#  'mistak',
#  'dissatisfact',
#  'work',
#  'may',
#  'ascrib',
#  'pass',
#  'perfect',
#  'workm',
#  'dea',
#  'prev',
#  'attain',
#  'encycloped',
#  'brittanic',
#  'bil',
#  'walsh',
#  'whos',
#  'coach',
#  'car',
#  'ut',
#  'destroy',
#  'would',
#  'sit',
#  'daz',
#  'hot',
#  'tub',
#  'ev',
#  'win',
#  'despond',
#  'miscalc',
#  'play',
#  'two',
#  'tort',
#  'person',
#  'walsh',
#  'lat',
#  'told',
#  'biograph',
#  'har',
#  'felt',
#  'fail',
#  'person',
#  'ev',
#  'couldnt',
#  'get',
#  'cant',
#  'liv',
#  'way',
#  'long',
#  'attack',
#  'part',
#  'nerv',
#  'system',
#  'many',
#  'tim',
#  'seth',
#  'wickersham',
#  'book',
#  'coach',
#  'im',
#  'anywh',
#  'near',
#  'level',
#  'peopl',
#  'right',
#  'tel',
#  'liv',
#  'diff',
#  'shud',
#  'think',
#  'much',
#  'farth',
#  'could',
#  'gon',
#  'pract',
#  'bet',
#  'approach',
#  'prosa',
#  'tend',
#  'correl',
#  'stun',
#  'numb',
#  'maladapt',
#  'pattern',
#  'oft',
#  'caus',
#  'four',
#  'procrastin',
#  'fear',
#  'fail',
#  'delay',
#  'complex',
#  'uncertain',
#  'task',
#  'perfect',
#  'procrastin',
#  'avoid',
#  'confront',
#  'imperfect',
#  'also',
#  'slow',
#  'ask',
#  'help',
#  'would',
#  'mean',
#  'admit',
#  'she',
#  'struggling',
#  'impost',
#  'syndrom',
#  'fear',
#  'found',
#  'judg',
#  'unworthy',
#  'smart',
#  'cap',
#  'good',
#  'enough',
#  'meet',
#  'id',
#  'standard',
#  'perfect',
#  'blend',
#  'act',
#  'part',
#  'fear',
#  'found',
#  'reject',
#  'obsess',
#  'compuls',
#  'ful',
#  'ocd',
#  'mild',
#  'form',
#  'exampl',
#  'recur',
#  'anxy',
#  'fear',
#  'inadequ',
#  'lead',
#  'selfsooth',
#  'respons',
#  'scrolling',
#  'twit',
#  'hour',
#  'burnout',
#  'see',
#  'kind',
#  'ptsd',
#  'defenseless',
#  'perfect',
#  'chronically',
#  'fail',
#  'liv',
#  'id',
#  'end',
#  'deep',
#  'emot',
#  'traum',
#  'worst',
#  'cas',
#  'los',
#  'sens',
#  'selfwor',
#  'perfect',
#  'might',
#  'restrict',
#  'on',
#  'domain',
#  'cor',
#  'tend',
#  'tend',
#  'cut',
#  'across',
#  'realm',
#  'lif',
#  'qual',
#  'mak',
#  'valu',
#  'insidy',
#  'iv',
#  'altern',
#  'much',
#  'perfect',
#  'learn',
#  'childr',
#  'choos',
#  'adult',
#  'ext',
#  'choos',
#  'fool',
#  'cho',
#  'unlearn',
#  'perfect',
#  'on',
#  'altern',
#  'simil',
#  'flav',
#  'excel',
#  'diff',
#  'two',
#  'respect',
#  'perfect',
#  'focus',
#  'achiev',
#  'excel',
#  'focus',
#  'pursu',
#  'success',
#  'fail',
#  'ar',
#  'ev',
#  'ful',
#  'control',
#  'control',
#  'choos',
#  'right',
#  'mom',
#  'at',
#  'shift',
#  'outcom',
#  'process',
#  'perfect',
#  'focus',
#  'fix',
#  'outcom',
#  'excel',
#  'focus',
#  'bet',
#  'outcom',
#  'real',
#  'situ',
#  'alway',
#  'improv',
#  'sint',
#  'perfect',
#  'outcom',
#  'perfect',
#  'imposs',
#  'let',
#  'see',
#  'tend',
#  'clear',
#  'revisit',
#  'perfect',
#  'ear',
#  'form',
#  'perfect',
#  'prid',
#  'work',
#  'hard',
#  'pay',
#  'at',
#  'pres',
#  'feel',
#  'gre',
#  'satisfact',
#  'start',
#  'new',
#  'project',
#  'steady',
#  'confid',
#  'end',
#  'regardless',
#  'difficul',
#  'underfoot',
#  'work',
#  'uncertain',
#  'persist',
#  'uncertainty',
#  'unknown',
#  'long',
#  'threat',
#  'mat',
#  'focus',
#  'tak',
#  'next',
#  'step',
#  'sint',
#  'embrac',
#  'imperfect',
#  'giv',
#  'sint',
#  'effort',
#  'regardless',
#  'mot',
#  'feel',
#  'lif',
#  'littl',
#  'difficul',
#  'enough',
#  'det',
#  'project',
#  'hard',
#  'enough',
#  'setback',
#  'fail',
#  'inevit',
#  'learn',
#  'much',
#  'tre',
#  'lik',
#  'precy',
#  'friend',
#  'ar',
#  'exact',
#  'pleas',
#  'show',
#  'improv',
#  'grow',
#  'hasnt',
#  'fail',
#  'rec',
#  'know',
#  'she',
#  'play',
#  'saf',
#  'feel',
#  'stuck',
#  'problem',
#  'ask',
#  'help',
#  'adv',
#  'may',
#  'feel',
#  'us',
#  'anxy',
#  'stresses',
#  'big',
#  'project',
#  'worry',
#  'long',
#  'selfinflict',
#  'gen',
#  'ser',
#  'steady',
#  'feel',
#  'work',
#  'good',
#  'enough',
#  'complet',
#  'mov',
#  'oth',
#  'achiev',
#  'bet',
#  'outcom',
#  'respond',
#  'op',
#  'curios',
#  'someth',
#  'learn',
#  'glad',
#  'absorb',
#  'lesson',
#  'illwil',
#  'focus',
#  'control',
#  'pursuit',
#  'outcom',
#  'opt',
#  'comparison',
#  'gam',
#  'alway',
#  'root',
#  'real',
#  'mom',
#  'process',
#  'outcom',
#  'system',
#  'goal',
#  'grow',
#  'mindset',
#  'fix',
#  'mindset',
#  'satisf',
#  'maxim',
#  'profess',
#  'am',
#  'bor',
#  'funda',
#  'flashy',
#  'trick',
#  'respons',
#  'react',
#  'ag',
#  'pass',
#  'pres',
#  'regret',
#  'worry',
#  'mat',
#  'cal',
#  'distinct',
#  'dont',
#  'claim',
#  'get',
#  'easy',
#  'hard',
#  'expert',
#  'poss',
#  'put',
#  'work',
#  'enough',
#  'tim',
#  'pract',
#  'becom',
#  'autom',
#  'v',
#  'way',
#  'cruel',
#  'paradox',
#  'precondit',
#  'mean',
#  'chang',
#  'want',
#  'chang',
#  'believ',
#  'chang',
#  'poss',
#  'commit',
#  'regul',
#  'pract',
#  'run',
#  'tend',
#  'enough',
#  'selfinsight',
#  'enough',
#  'selfinflict',
#  'suff',
#  'perfect',
#  'ar',
#  'broad',
#  'speak',
#  'way',
#  'three',
#  'part',
#  'first',
#  'train',
#  'mind',
#  'see',
#  'end',
#  'imperfect',
#  'real',
#  'psycholog',
#  'lit',
#  'recommend',
#  'vary',
#  'tre',
#  'opt',
#  'depend',
#  'situ',
#  'three',
#  'cognitivebehavy',
#  'therapy',
#  'train',
#  'mind',
#  'challeng',
#  'distort',
#  'thought',
#  'rel',
#  'perfect',
#  'eg',
#  'im',
#  'fail',
#  'might',
#  'fail',
#  'im',
#  'success',
#  'way',
#  'expos',
#  'respons',
#  'prev',
#  'train',
#  'mind',
#  'tol',
#  'reduc',
#  'ment',
#  'distress',
#  'rep',
#  'fac',
#  'distress',
#  'thought',
#  'eg',
#  'im',
#  'going',
#  'fail',
#  'ye',
#  'mayb',
#  'mind',
#  'medit',
#  'train',
#  ...]

# %% [markdown]
# ## Evaluation

# %%
df = pd.DataFrame({
    'word': filtered_words,
    'POS': [tag for _, tag in pos_tags],
    'lemma': lemmas,
    'porter': porter_stems,
    'snowball': snowball_stems,
    'lancaster': lancaster_stems
})
df
# Out:
#                word  POS          lemma      porter    snowball lancaster
# 0        unlearning   JJ     unlearning     unlearn     unlearn   unlearn
# 1     perfectionism   NN  perfectionism  perfection  perfection   perfect
# 2            common   JJ         common      common      common    common
# 3              idea   NN           idea        idea        idea       ide
# 4     perfectionism   NN  perfectionism  perfection  perfection   perfect
# ...             ...  ...            ...         ...         ...       ...
# 1120            way   NN            way         way         way       way
# 1121          thats  NNS          thats        that        that      that
# 1122          takes  VBZ           take        take        take       tak
# 1123            get   NN            get         get         get       get
# 1124        started  VBD        started       start       start     start
#
# [1125 rows x 6 columns]

# %% [markdown]
# Save results to CSV

# %%
df.to_csv('results.csv', index=False)
